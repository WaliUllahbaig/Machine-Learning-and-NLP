# %% [markdown]
# # **Natural Language Processing**

# %% [markdown]
# # **Group Member Names:**
#
# ### **Shah Wali Ullah Baig - 191980008**

# %% [markdown]
# # **Accessing GPU Resources**

# %% [markdown]
# To access GPU resources in Google Colab, go to the "Runtime" option (located in the centre of the navigationbar's options), choose "Change runtime Type", click the downward arrow, select "GPU", and click save.

# %% [markdown]
# We will access our datasets from Google Drive to Collaborate directly by connecting them. But before making the connection, we will create a folder in our drive and upload the dataset file (zip file) to that folder.

# %% [markdown]
# # **Connect Colab with Google Drive**

# %% [markdown]
# To connect Google Colab with Google Drive, first we will import the drive library from Google.colab pakage and mount it, then run this code.
#
# After running this code, he will ask for permission to connect. Simply choose the 'Connect to Google Drive' option. Then a new window will appear with a list of Google accounts (if you are logged in multiple accounts). Choose a Google account with whose drive you want to connect, and lastly, press the 'Allow' button.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Unzip the Folder**

# %% [markdown]
# To unzip the folder, we will simply use the 'unzip' keyword and give it the path of the zip file (uploaded on the drive) and run this cell. It will automatically make a folder in Google Colab files with the same name as the zip file's name.
#
# To get the path, go to that zip file, right click on it and select 'Get link'. There will be an option to "copy link".

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/NLP-Project/acllmdb.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: aclImdb/train/unsup/5504_0.txt
#   inflating: aclImdb/train/unsup/5505_0.txt
#   inflating: aclImdb/train/unsup/5506_0.txt
#   inflating: aclImdb/train/unsup/5507_0.txt
#   inflating: aclImdb/train/unsup/5508_0.txt
#   inflating: aclImdb/train/unsup/5509_0.txt
#   inflating: aclImdb/train/unsup/550_0.txt
#   inflating: aclImdb/train/unsup/5510_0.txt
#   inflating: aclImdb/train/unsup/5511_0.txt
#   inflating: aclImdb/train/unsup/5512_0.txt
#   inflating: aclImdb/train/unsup/5513_0.txt
#   inflating: aclImdb/train/unsup/5514_0.txt
#   inflating: aclImdb/train/unsup/5515_0.txt
#   inflating: aclImdb/train/unsup/5516_0.txt
#   inflating: aclImdb/train/unsup/5517_0.txt
#   inflating: aclImdb/train/unsup/5518_0.txt
#   inflating: aclImdb/train/unsup/5519_0.txt
#   inflating: aclImdb/train/unsup/551_0.txt
#   inflating: aclImdb/train/unsup/5520_0.txt
#   inflating: aclImdb/train/unsup/5521_0.txt
#   inflating: aclImdb/train/unsup/5522_0.txt
#   inflating: aclImdb/train/unsup/5523_0.txt
#   inflating: aclImdb/train/unsup/5524_0.txt
#   inflating: aclImdb/train/unsup/5525_0.txt
#   inflating: aclImdb/train/unsup/5526_0.txt
#   inflating: aclImdb/train/unsup/5527_0.txt
#   inflating: aclImdb/train/unsup/5528_0.txt
#   inflating: aclImdb/train/unsup/5529_0.txt
#   inflating: aclImdb/train/unsup/552_0.txt
#   inflating: aclImdb/train/unsup/5530_0.txt
#   inflating: aclImdb/train/unsup/5531_0.txt
#   inflating: aclImdb/train/unsup/5532_0.txt
#   inflating: aclImdb/train/unsup/5533_0.txt
#   inflating: aclImdb/train/unsup/5534_0.txt
#   inflating: aclImdb/train/unsup/5535_0.txt
#   inflating: aclImdb/train/unsup/5536_0.txt
#   inflating: aclImdb/train/unsup/5537_0.txt
#   inflating: aclImdb/train/unsup/5538_0.txt
#   inflating: aclImdb/train/unsup/5539_0.txt
#   inflating: aclImdb/train/unsup/553_0.txt
#   inflating: aclImdb/train/unsup/5540_0.txt
#   inflating: aclImdb/train/unsup/5541_0.txt
#   inflating: aclImdb/train/unsup/5542_0.txt
#   inflating: aclImdb/train/unsup/5543_0.txt
#   inflating: aclImdb/train/unsup/5544_0.txt
#   inflating: aclImdb/train/unsup/5545_0.txt
#   inflating: aclImdb/train/unsup/5546_0.txt
#   inflating: aclImdb/train/unsup/5547_0.txt
#   inflating: aclImdb/train/unsup/5548_0.txt
#   inflating: aclImdb/train/unsup/5549_0.txt
#   inflating: aclImdb/train/unsup/554_0.txt
#   inflating: aclImdb/train/unsup/5550_0.txt
#   inflating: aclImdb/train/unsup/5551_0.txt
#   inflating: aclImdb/train/unsup/5552_0.txt
#   inflating: aclImdb/train/unsup/5553_0.txt
#   inflating: aclImdb/train/unsup/5554_0.txt
#   inflating: aclImdb/train/unsup/5555_0.txt
#   inflating: aclImdb/train/unsup/5556_0.txt
#   inflating: aclImdb/train/unsup/5557_0.txt
#   inflating: aclImdb/train/unsup/5558_0.txt
#   inflating: aclImdb/train/unsup/5559_0.txt
#   inflating: aclImdb/train/unsup/555_0.txt
#   inflating: aclImdb/train/unsup/5560_0.txt
#   inflating: aclImdb/train/unsup/5561_0.txt
#   inflating: aclImdb/train/unsup/5562_0.txt
#   inflating: aclImdb/train/unsup/5563_0.txt
#   inflating: aclImdb/train/unsup/5564_0.txt
#   inflating: aclImdb/train/unsup/5565_0.txt
#   inflating: aclImdb/train/unsup/5566_0.txt
#   inflating: aclImdb/train/unsup/5567_0.txt
#   inflating: aclImdb/train/unsup/5568_0.txt
#   inflating: aclImdb/train/unsup/5569_0.txt
#   inflating: aclImdb/train/unsup/556_0.txt
#   inflating: aclImdb/train/unsup/5570_0.txt
#   inflating: aclImdb/train/unsup/5571_0.txt
#   inflating: aclImdb/train/unsup/5572_0.txt
#   inflating: aclImdb/train/unsup/5573_0.txt
#   inflating: aclImdb/train/unsup/5574_0.txt
#   inflating: aclImdb/train/unsup/5575_0.txt
#   inflating: aclImdb/train/unsup/5576_0.txt
#   inflating: aclImdb/train/unsup/5577_0.txt
#   inflating: aclImdb/train/unsup/5578_0.txt
#   inflating: aclImdb/train/unsup/5579_0.txt
#   inflating: aclImdb/train/unsup/557_0.txt
#   inflating: aclImdb/train/unsup/5580_0.txt
#   inflating: aclImdb/train/unsup/5581_0.txt
#   inflating: aclImdb/train/unsup/5582_0.txt
#   inflating: aclImdb/train/unsup/5583_0.txt
#   inflating: aclImdb/train/unsup/5584_0.txt
#   inflating: aclImdb/train/unsup/5585_0.txt
#   inflating: aclImdb/train/unsup/5586_0.txt
#   inflating: aclImdb/train/unsup/5587_0.txt
#   inflating: aclImdb/train/unsup/5588_0.txt
#   inflating: aclImdb/train/unsup/5589_0.txt
#   inflating: aclImdb/train/unsup/558_0.txt
#   inflating: aclImdb/train/unsup/5590_0.txt
#   inflating: aclImdb/train/unsup/5591_0.txt
#   inflating: aclImdb/train/unsup/5592_0.txt
#   inflating: aclImdb/train/unsup/5593_0.txt
#   inflating: aclImdb/train/unsup/5594_0.txt
#   inflating: aclImdb/train/unsup/5595_0.txt
#   inflating: aclImdb/train/unsup/5596_0.txt
#   inflating: aclImdb/train/unsup/5597_0.txt
#   inflating: aclImdb/train/unsup/5598_0.txt
#   inflating: aclImdb/train/unsup/5599_0.txt
#   inflating: aclImdb/train/unsup/559_0.txt
#   inflating: aclImdb/train/unsup/55_0.txt
#   inflating: aclImdb/train/unsup/5600_0.txt
#   inflating: aclImdb/train/unsup/5601_0.txt
#   inflating: aclImdb/train/unsup/5602_0.txt
#   inflating: aclImdb/train/unsup/5603_0.txt
#   inflating: aclImdb/train/unsup/5604_0.txt
#   inflating: aclImdb/train/unsup/5605_0.txt
#   inflating: aclImdb/train/unsup/5606_0.txt
#   inflating: aclImdb/train/unsup/5607_0.txt
#   inflating: aclImdb/train/unsup/5608_0.txt
#   inflating: aclImdb/train/unsup/5609_0.txt
#   inflating: aclImdb/train/unsup/560_0.txt
#   inflating: aclImdb/train/unsup/5610_0.txt
#   inflating: aclImdb/train/unsup/5611_0.txt
#   inflating: aclImdb/train/unsup/5612_0.txt
#   inflating: aclImdb/train/unsup/5613_0.txt
#   inflating: aclImdb/train/unsup/5614_0.txt
#   inflating: aclImdb/train/unsup/5615_0.txt
#   inflating: aclImdb/train/unsup/5616_0.txt
#   inflating: aclImdb/train/unsup/5617_0.txt
#   inflating: aclImdb/train/unsup/5618_0.txt
#   inflating: aclImdb/train/unsup/5619_0.txt
#   inflating: aclImdb/train/unsup/561_0.txt
#   inflating: aclImdb/train/unsup/5620_0.txt
#   inflating: aclImdb/train/unsup/5621_0.txt
#   inflating: aclImdb/train/unsup/5622_0.txt
#   inflating: aclImdb/train/unsup/5623_0.txt
#   inflating: aclImdb/train/unsup/5624_0.txt
#   inflating: aclImdb/train/unsup/5625_0.txt
#   inflating: aclImdb/train/unsup/5626_0.txt
#   inflating: aclImdb/train/unsup/5627_0.txt
#   inflating: aclImdb/train/unsup/5628_0.txt
#   inflating: aclImdb/train/unsup/5629_0.txt
#   inflating: aclImdb/train/unsup/562_0.txt
#   inflating: aclImdb/train/unsup/5630_0.txt
#   inflating: aclImdb/train/unsup/5631_0.txt
#   inflating: aclImdb/train/unsup/5632_0.txt
#   inflating: aclImdb/train/unsup/5633_0.txt
#   inflating: aclImdb/train/unsup/5634_0.txt
#   inflating: aclImdb/train/unsup/5635_0.txt
#   inflating: aclImdb/train/unsup/5636_0.txt
#   inflating: aclImdb/train/unsup/5637_0.txt
#   inflating: aclImdb/train/unsup/5638_0.txt
#   inflating: aclImdb/train/unsup/5639_0.txt
#   inflating: aclImdb/train/unsup/563_0.txt
#   inflating: aclImdb/train/unsup/5640_0.txt
#   inflating: aclImdb/train/unsup/5641_0.txt
#   inflating: aclImdb/train/unsup/5642_0.txt
#   inflating: aclImdb/train/unsup/5643_0.txt
#   inflating: aclImdb/train/unsup/5644_0.txt
#   inflating: aclImdb/train/unsup/5645_0.txt
#   inflating: aclImdb/train/unsup/5646_0.txt
#   inflating: aclImdb/train/unsup/5647_0.txt
#   inflating: aclImdb/train/unsup/5648_0.txt
#   inflating: aclImdb/train/unsup/5649_0.txt
#   inflating: aclImdb/train/unsup/564_0.txt
#   inflating: aclImdb/train/unsup/5650_0.txt
#   inflating: aclImdb/train/unsup/5651_0.txt
#   inflating: aclImdb/train/unsup/5652_0.txt
#   inflating: aclImdb/train/unsup/5653_0.txt
#   inflating: aclImdb/train/unsup/5654_0.txt
#   inflating: aclImdb/train/unsup/5655_0.txt
#   inflating: aclImdb/train/unsup/5656_0.txt
#   inflating: aclImdb/train/unsup/5657_0.txt
#   inflating: aclImdb/train/unsup/5658_0.txt
#   inflating: aclImdb/train/unsup/5659_0.txt
#   inflating: aclImdb/train/unsup/565_0.txt
#   inflating: aclImdb/train/unsup/5660_0.txt
#   inflating: aclImdb/train/unsup/5661_0.txt
#   inflating: aclImdb/train/unsup/5662_0.txt
#   inflating: aclImdb/train/unsup/5663_0.txt
#   inflating: aclImdb/train/unsup/5664_0.txt
#   inflating: aclImdb/train/unsup/5665_0.txt
#   inflating: aclImdb/train/unsup/5666_0.txt
#   inflating: aclImdb/train/unsup/5667_0.txt
#   inflating: aclImdb/train/unsup/5668_0.txt
#   inflating: aclImdb/train/unsup/5669_0.txt
#   inflating: aclImdb/train/unsup/566_0.txt
#   inflating: aclImdb/train/unsup/5670_0.txt
#   inflating: aclImdb/train/unsup/5671_0.txt
#   inflating: aclImdb/train/unsup/5672_0.txt
#   inflating: aclImdb/train/unsup/5673_0.txt
#   inflating: aclImdb/train/unsup/5674_0.txt
#   inflating: aclImdb/train/unsup/5675_0.txt
#   inflating: aclImdb/train/unsup/5676_0.txt
#   inflating: aclImdb/train/unsup/5677_0.txt
#   inflating: aclImdb/train/unsup/5678_0.txt
#   inflating: aclImdb/train/unsup/5679_0.txt
#   inflating: aclImdb/train/unsup/567_0.txt
#   inflating: aclImdb/train/unsup/5680_0.txt
#   inflating: aclImdb/train/unsup/5681_0.txt
#   inflating: aclImdb/train/unsup/5682_0.txt
#   inflating: aclImdb/train/unsup/5683_0.txt
#   inflating: aclImdb/train/unsup/5684_0.txt
#   inflating: aclImdb/train/unsup/5685_0.txt
#   inflating: aclImdb/train/unsup/5686_0.txt
#   inflating: aclImdb/train/unsup/5687_0.txt
#   inflating: aclImdb/train/unsup/5688_0.txt
#   inflating: aclImdb/train/unsup/5689_0.txt
#   inflating: aclImdb/train/unsup/568_0.txt
#   inflating: aclImdb/train/unsup/5690_0.txt
#   inflating: aclImdb/train/unsup/5691_0.txt
#   inflating: aclImdb/train/unsup/5692_0.txt
#   inflating: aclImdb/train/unsup/5693_0.txt
#   inflating: aclImdb/train/unsup/5694_0.txt
#   inflating: aclImdb/train/unsup/5695_0.txt
#   inflating: aclImdb/train/unsup/5696_0.txt
#   inflating: aclImdb/train/unsup/5697_0.txt
#   inflating: aclImdb/train/unsup/5698_0.txt
#   inflating: aclImdb/train/unsup/5699_0.txt
#   inflating: aclImdb/train/unsup/569_0.txt
#   inflating: aclImdb/train/unsup/56_0.txt
#   inflating: aclImdb/train/unsup/5700_0.txt
#   inflating: aclImdb/train/unsup/5701_0.txt
#   inflating: aclImdb/train/unsup/5702_0.txt
#   inflating: aclImdb/train/unsup/5703_0.txt
#   inflating: aclImdb/train/unsup/5704_0.txt
#   inflating: aclImdb/train/unsup/5705_0.txt
#   inflating: aclImdb/train/unsup/5706_0.txt
#   inflating: aclImdb/train/unsup/5707_0.txt
#   inflating: aclImdb/train/unsup/5708_0.txt
#   inflating: aclImdb/train/unsup/5709_0.txt
#   inflating: aclImdb/train/unsup/570_0.txt
#   inflating: aclImdb/train/unsup/5710_0.txt
#   inflating: aclImdb/train/unsup/5711_0.txt
#   inflating: aclImdb/train/unsup/5712_0.txt
#   inflating: aclImdb/train/unsup/5713_0.txt
#   inflating: aclImdb/train/unsup/5714_0.txt
#   inflating: aclImdb/train/unsup/5715_0.txt
#   inflating: aclImdb/train/unsup/5716_0.txt
#   inflating: aclImdb/train/unsup/5717_0.txt
#   inflating: aclImdb/train/unsup/5718_0.txt
#   inflating: aclImdb/train/unsup/5719_0.txt
#   inflating: aclImdb/train/unsup/571_0.txt
#   inflating: aclImdb/train/unsup/5720_0.txt
#   inflating: aclImdb/train/unsup/5721_0.txt
#   inflating: aclImdb/train/unsup/5722_0.txt
#   inflating: aclImdb/train/unsup/5723_0.txt
#   inflating: aclImdb/train/unsup/5724_0.txt
#   inflating: aclImdb/train/unsup/5725_0.txt
#   inflating: aclImdb/train/unsup/5726_0.txt
#   inflating: aclImdb/train/unsup/5727_0.txt
#   inflating: aclImdb/train/unsup/5728_0.txt
#   inflating: aclImdb/train/unsup/5729_0.txt
#   inflating: aclImdb/train/unsup/572_0.txt
#   inflating: aclImdb/train/unsup/5730_0.txt
#   inflating: aclImdb/train/unsup/5731_0.txt
#   inflating: aclImdb/train/unsup/5732_0.txt
#   inflating: aclImdb/train/unsup/5733_0.txt
#   inflating: aclImdb/train/unsup/5734_0.txt
#   inflating: aclImdb/train/unsup/5735_0.txt
#   inflating: aclImdb/train/unsup/5736_0.txt
#   inflating: aclImdb/train/unsup/5737_0.txt
#   inflating: aclImdb/train/unsup/5738_0.txt
#   inflating: aclImdb/train/unsup/5739_0.txt
#   inflating: aclImdb/train/unsup/573_0.txt
#   inflating: aclImdb/train/unsup/5740_0.txt
#   inflating: aclImdb/train/unsup/5741_0.txt
#   inflating: aclImdb/train/unsup/5742_0.txt
#   inflating: aclImdb/train/unsup/5743_0.txt
#   inflating: aclImdb/train/unsup/5744_0.txt
#   inflating: aclImdb/train/unsup/5745_0.txt
#   inflating: aclImdb/train/unsup/5746_0.txt
#   inflating: aclImdb/train/unsup/5747_0.txt
#   inflating: aclImdb/train/unsup/5748_0.txt
#   inflating: aclImdb/train/unsup/5749_0.txt
#   inflating: aclImdb/train/unsup/574_0.txt
#   inflating: aclImdb/train/unsup/5750_0.txt
#   inflating: aclImdb/train/unsup/5751_0.txt
#   inflating: aclImdb/train/unsup/5752_0.txt
#   inflating: aclImdb/train/unsup/5753_0.txt
#   inflating: aclImdb/train/unsup/5754_0.txt
#   inflating: aclImdb/train/unsup/5755_0.txt
#   inflating: aclImdb/train/unsup/5756_0.txt
#   inflating: aclImdb/train/unsup/5757_0.txt
#   inflating: aclImdb/train/unsup/5758_0.txt
#   inflating: aclImdb/train/unsup/5759_0.txt
#   inflating: aclImdb/train/unsup/575_0.txt
#   inflating: aclImdb/train/unsup/5760_0.txt
#   inflating: aclImdb/train/unsup/5761_0.txt
#   inflating: aclImdb/train/unsup/5762_0.txt
#   inflating: aclImdb/train/unsup/5763_0.txt
#   inflating: aclImdb/train/unsup/5764_0.txt
#   inflating: aclImdb/train/unsup/5765_0.txt
#   inflating: aclImdb/train/unsup/5766_0.txt
#   inflating: aclImdb/train/unsup/5767_0.txt
#   inflating: aclImdb/train/unsup/5768_0.txt
#   inflating: aclImdb/train/unsup/5769_0.txt
#   inflating: aclImdb/train/unsup/576_0.txt
#   inflating: aclImdb/train/unsup/5770_0.txt
#   inflating: aclImdb/train/unsup/5771_0.txt
#   inflating: aclImdb/train/unsup/5772_0.txt
#   inflating: aclImdb/train/unsup/5773_0.txt
#   inflating: aclImdb/train/unsup/5774_0.txt
#   inflating: aclImdb/train/unsup/5775_0.txt
#   inflating: aclImdb/train/unsup/5776_0.txt
#   inflating: aclImdb/train/unsup/5777_0.txt
#   inflating: aclImdb/train/unsup/5778_0.txt
#   inflating: aclImdb/train/unsup/5779_0.txt
#   inflating: aclImdb/train/unsup/577_0.txt
#   inflating: aclImdb/train/unsup/5780_0.txt
#   inflating: aclImdb/train/unsup/5781_0.txt
#   inflating: aclImdb/train/unsup/5782_0.txt
#   inflating: aclImdb/train/unsup/5783_0.txt
#   inflating: aclImdb/train/unsup/5784_0.txt
#   inflating: aclImdb/train/unsup/5785_0.txt
#   inflating: aclImdb/train/unsup/5786_0.txt
#   inflating: aclImdb/train/unsup/5787_0.txt
#   inflating: aclImdb/train/unsup/5788_0.txt
#   inflating: aclImdb/train/unsup/5789_0.txt
#   inflating: aclImdb/train/unsup/578_0.txt
#   inflating: aclImdb/train/unsup/5790_0.txt
#   inflating: aclImdb/train/unsup/5791_0.txt
#   inflating: aclImdb/train/unsup/5792_0.txt
#   inflating: aclImdb/train/unsup/5793_0.txt
#   inflating: aclImdb/train/unsup/5794_0.txt
#   inflating: aclImdb/train/unsup/5795_0.txt
#   inflating: aclImdb/train/unsup/5796_0.txt
#   inflating: aclImdb/train/unsup/5797_0.txt
#   inflating: aclImdb/train/unsup/5798_0.txt
#   inflating: aclImdb/train/unsup/5799_0.txt
#   inflating: aclImdb/train/unsup/579_0.txt
#   inflating: aclImdb/train/unsup/57_0.txt
#   inflating: aclImdb/train/unsup/5800_0.txt
#   inflating: aclImdb/train/unsup/5801_0.txt
#   inflating: aclImdb/train/unsup/5802_0.txt
#   inflating: aclImdb/train/unsup/5803_0.txt
#   inflating: aclImdb/train/unsup/5804_0.txt
#   inflating: aclImdb/train/unsup/5805_0.txt
#   inflating: aclImdb/train/unsup/5806_0.txt
#   inflating: aclImdb/train/unsup/5807_0.txt
#   inflating: aclImdb/train/unsup/5808_0.txt
#   inflating: aclImdb/train/unsup/5809_0.txt
#   inflating: aclImdb/train/unsup/580_0.txt
#   inflating: aclImdb/train/unsup/5810_0.txt
#   inflating: aclImdb/train/unsup/5811_0.txt
#   inflating: aclImdb/train/unsup/5812_0.txt
#   inflating: aclImdb/train/unsup/5813_0.txt
#   inflating: aclImdb/train/unsup/5814_0.txt
#   inflating: aclImdb/train/unsup/5815_0.txt
#   inflating: aclImdb/train/unsup/5816_0.txt
#   inflating: aclImdb/train/unsup/5817_0.txt
#   inflating: aclImdb/train/unsup/5818_0.txt
#   inflating: aclImdb/train/unsup/5819_0.txt
#   inflating: aclImdb/train/unsup/581_0.txt
#   inflating: aclImdb/train/unsup/5820_0.txt
#   inflating: aclImdb/train/unsup/5821_0.txt
#   inflating: aclImdb/train/unsup/5822_0.txt
#   inflating: aclImdb/train/unsup/5823_0.txt
#   inflating: aclImdb/train/unsup/5824_0.txt
#   inflating: aclImdb/train/unsup/5825_0.txt
#   inflating: aclImdb/train/unsup/5826_0.txt
#   inflating: aclImdb/train/unsup/5827_0.txt
#   inflating: aclImdb/train/unsup/5828_0.txt
#   inflating: aclImdb/train/unsup/5829_0.txt
#   inflating: aclImdb/train/unsup/582_0.txt
#   inflating: aclImdb/train/unsup/5830_0.txt
#   inflating: aclImdb/train/unsup/5831_0.txt
#   inflating: aclImdb/train/unsup/5832_0.txt
#   inflating: aclImdb/train/unsup/5833_0.txt
#   inflating: aclImdb/train/unsup/5834_0.txt
#   inflating: aclImdb/train/unsup/5835_0.txt
#   inflating: aclImdb/train/unsup/5836_0.txt
#   inflating: aclImdb/train/unsup/5837_0.txt
#   inflating: aclImdb/train/unsup/5838_0.txt
#   inflating: aclImdb/train/unsup/5839_0.txt
#   inflating: aclImdb/train/unsup/583_0.txt
#   inflating: aclImdb/train/unsup/5840_0.txt
#   inflating: aclImdb/train/unsup/5841_0.txt
#   inflating: aclImdb/train/unsup/5842_0.txt
#   inflating: aclImdb/train/unsup/5843_0.txt
#   inflating: aclImdb/train/unsup/5844_0.txt
#   inflating: aclImdb/train/unsup/5845_0.txt
#   inflating: aclImdb/train/unsup/5846_0.txt
#   inflating: aclImdb/train/unsup/5847_0.txt
#   inflating: aclImdb/train/unsup/5848_0.txt
#   inflating: aclImdb/train/unsup/5849_0.txt
#   inflating: aclImdb/train/unsup/584_0.txt
#   inflating: aclImdb/train/unsup/5850_0.txt
#   inflating: aclImdb/train/unsup/5851_0.txt
#   inflating: aclImdb/train/unsup/5852_0.txt
#   inflating: aclImdb/train/unsup/5853_0.txt
#   inflating: aclImdb/train/unsup/5854_0.txt
#   inflating: aclImdb/train/unsup/5855_0.txt
#   inflating: aclImdb/train/unsup/5856_0.txt
#   inflating: aclImdb/train/unsup/5857_0.txt
#   inflating: aclImdb/train/unsup/5858_0.txt
#   inflating: aclImdb/train/unsup/5859_0.txt
#   inflating: aclImdb/train/unsup/585_0.txt
#   inflating: aclImdb/train/unsup/5860_0.txt
#   inflating: aclImdb/train/unsup/5861_0.txt
#   inflating: aclImdb/train/unsup/5862_0.txt
#   inflating: aclImdb/train/unsup/5863_0.txt
#   inflating: aclImdb/train/unsup/5864_0.txt
#   inflating: aclImdb/train/unsup/5865_0.txt
#   inflating: aclImdb/train/unsup/5866_0.txt
#   inflating: aclImdb/train/unsup/5867_0.txt
#   inflating: aclImdb/train/unsup/5868_0.txt
#   inflating: aclImdb/train/unsup/5869_0.txt
#   inflating: aclImdb/train/unsup/586_0.txt
#   inflating: aclImdb/train/unsup/5870_0.txt
#   inflating: aclImdb/train/unsup/5871_0.txt
#   inflating: aclImdb/train/unsup/5872_0.txt
#   inflating: aclImdb/train/unsup/5873_0.txt
#   inflating: aclImdb/train/unsup/5874_0.txt
#   inflating: aclImdb/train/unsup/5875_0.txt
#   inflating: aclImdb/train/unsup/5876_0.txt
#   inflating: aclImdb/train/unsup/5877_0.txt
#   inflating: aclImdb/train/unsup/5878_0.txt
#   inflating: aclImdb/train/unsup/5879_0.txt
#   inflating: aclImdb/train/unsup/587_0.txt
#   inflating: aclImdb/train/unsup/5880_0.txt
#   inflating: aclImdb/train/unsup/5881_0.txt
#   inflating: aclImdb/train/unsup/5882_0.txt
#   inflating: aclImdb/train/unsup/5883_0.txt
#   inflating: aclImdb/train/unsup/5884_0.txt
#   inflating: aclImdb/train/unsup/5885_0.txt
#   inflating: aclImdb/train/unsup/5886_0.txt
#   inflating: aclImdb/train/unsup/5887_0.txt
#   inflating: aclImdb/train/unsup/5888_0.txt
#   inflating: aclImdb/train/unsup/5889_0.txt
#   inflating: aclImdb/train/unsup/588_0.txt
#   inflating: aclImdb/train/unsup/5890_0.txt
#   inflating: aclImdb/train/unsup/5891_0.txt
#   inflating: aclImdb/train/unsup/5892_0.txt
#   inflating: aclImdb/train/unsup/5893_0.txt
#   inflating: aclImdb/train/unsup/5894_0.txt
#   inflating: aclImdb/train/unsup/5895_0.txt
#   inflating: aclImdb/train/unsup/5896_0.txt
#   inflating: aclImdb/train/unsup/5897_0.txt
#   inflating: aclImdb/train/unsup/5898_0.txt
#   inflating: aclImdb/train/unsup/5899_0.txt
#   inflating: aclImdb/train/unsup/589_0.txt
#   inflating: aclImdb/train/unsup/58_0.txt
#   inflating: aclImdb/train/unsup/5900_0.txt
#   inflating: aclImdb/train/unsup/5901_0.txt
#   inflating: aclImdb/train/unsup/5902_0.txt
#   inflating: aclImdb/train/unsup/5903_0.txt
#   inflating: aclImdb/train/unsup/5904_0.txt
#   inflating: aclImdb/train/unsup/5905_0.txt
#   inflating: aclImdb/train/unsup/5906_0.txt
#   inflating: aclImdb/train/unsup/5907_0.txt
#   inflating: aclImdb/train/unsup/5908_0.txt
#   inflating: aclImdb/train/unsup/5909_0.txt
#   inflating: aclImdb/train/unsup/590_0.txt
#   inflating: aclImdb/train/unsup/5910_0.txt
#   inflating: aclImdb/train/unsup/5911_0.txt
#   inflating: aclImdb/train/unsup/5912_0.txt
#   inflating: aclImdb/train/unsup/5913_0.txt
#   inflating: aclImdb/train/unsup/5914_0.txt
#   inflating: aclImdb/train/unsup/5915_0.txt
#   inflating: aclImdb/train/unsup/5916_0.txt
#   inflating: aclImdb/train/unsup/5917_0.txt
#   inflating: aclImdb/train/unsup/5918_0.txt
#   inflating: aclImdb/train/unsup/5919_0.txt
#   inflating: aclImdb/train/unsup/591_0.txt
#   inflating: aclImdb/train/unsup/5920_0.txt
#   inflating: aclImdb/train/unsup/5921_0.txt
#   inflating: aclImdb/train/unsup/5922_0.txt
#   inflating: aclImdb/train/unsup/5923_0.txt
#   inflating: aclImdb/train/unsup/5924_0.txt
#   inflating: aclImdb/train/unsup/5925_0.txt
#   inflating: aclImdb/train/unsup/5926_0.txt
#   inflating: aclImdb/train/unsup/5927_0.txt
#   inflating: aclImdb/train/unsup/5928_0.txt
#   inflating: aclImdb/train/unsup/5929_0.txt
#   inflating: aclImdb/train/unsup/592_0.txt
#   inflating: aclImdb/train/unsup/5930_0.txt
#   inflating: aclImdb/train/unsup/5931_0.txt
#   inflating: aclImdb/train/unsup/5932_0.txt
#   inflating: aclImdb/train/unsup/5933_0.txt
#   inflating: aclImdb/train/unsup/5934_0.txt
#   inflating: aclImdb/train/unsup/5935_0.txt
#   inflating: aclImdb/train/unsup/5936_0.txt
#   inflating: aclImdb/train/unsup/5937_0.txt
#   inflating: aclImdb/train/unsup/5938_0.txt
#   inflating: aclImdb/train/unsup/5939_0.txt
#   inflating: aclImdb/train/unsup/593_0.txt
#   inflating: aclImdb/train/unsup/5940_0.txt
#   inflating: aclImdb/train/unsup/5941_0.txt
#   inflating: aclImdb/train/unsup/5942_0.txt
#   inflating: aclImdb/train/unsup/5943_0.txt
#   inflating: aclImdb/train/unsup/5944_0.txt
#   inflating: aclImdb/train/unsup/5945_0.txt
#   inflating: aclImdb/train/unsup/5946_0.txt
#   inflating: aclImdb/train/unsup/5947_0.txt
#   inflating: aclImdb/train/unsup/5948_0.txt
#   inflating: aclImdb/train/unsup/5949_0.txt
#   inflating: aclImdb/train/unsup/594_0.txt
#   inflating: aclImdb/train/unsup/5950_0.txt
#   inflating: aclImdb/train/unsup/5951_0.txt
#   inflating: aclImdb/train/unsup/5952_0.txt
#   inflating: aclImdb/train/unsup/5953_0.txt
#   inflating: aclImdb/train/unsup/5954_0.txt
#   inflating: aclImdb/train/unsup/5955_0.txt
#   inflating: aclImdb/train/unsup/5956_0.txt
#   inflating: aclImdb/train/unsup/5957_0.txt
#   inflating: aclImdb/train/unsup/5958_0.txt
#   inflating: aclImdb/train/unsup/5959_0.txt
#   inflating: aclImdb/train/unsup/595_0.txt
#   inflating: aclImdb/train/unsup/5960_0.txt
#   inflating: aclImdb/train/unsup/5961_0.txt
#   inflating: aclImdb/train/unsup/5962_0.txt
#   inflating: aclImdb/train/unsup/5963_0.txt
#   inflating: aclImdb/train/unsup/5964_0.txt
#   inflating: aclImdb/train/unsup/5965_0.txt
#   inflating: aclImdb/train/unsup/5966_0.txt
#   inflating: aclImdb/train/unsup/5967_0.txt
#   inflating: aclImdb/train/unsup/5968_0.txt
#   inflating: aclImdb/train/unsup/5969_0.txt
#   inflating: aclImdb/train/unsup/596_0.txt
#   inflating: aclImdb/train/unsup/5970_0.txt
#   inflating: aclImdb/train/unsup/5971_0.txt
#   inflating: aclImdb/train/unsup/5972_0.txt
#   inflating: aclImdb/train/unsup/5973_0.txt
#   inflating: aclImdb/train/unsup/5974_0.txt
#   inflating: aclImdb/train/unsup/5975_0.txt
#   inflating: aclImdb/train/unsup/5976_0.txt
#   inflating: aclImdb/train/unsup/5977_0.txt
#   inflating: aclImdb/train/unsup/5978_0.txt
#   inflating: aclImdb/train/unsup/5979_0.txt
#   inflating: aclImdb/train/unsup/597_0.txt
#   inflating: aclImdb/train/unsup/5980_0.txt
#   inflating: aclImdb/train/unsup/5981_0.txt
#   inflating: aclImdb/train/unsup/5982_0.txt
#   inflating: aclImdb/train/unsup/5983_0.txt
#   inflating: aclImdb/train/unsup/5984_0.txt
#   inflating: aclImdb/train/unsup/5985_0.txt
#   inflating: aclImdb/train/unsup/5986_0.txt
#   inflating: aclImdb/train/unsup/5987_0.txt
#   inflating: aclImdb/train/unsup/5988_0.txt
#   inflating: aclImdb/train/unsup/5989_0.txt
#   inflating: aclImdb/train/unsup/598_0.txt
#   inflating: aclImdb/train/unsup/5990_0.txt
#   inflating: aclImdb/train/unsup/5991_0.txt
#   inflating: aclImdb/train/unsup/5992_0.txt
#   inflating: aclImdb/train/unsup/5993_0.txt
#   inflating: aclImdb/train/unsup/5994_0.txt
#   inflating: aclImdb/train/unsup/5995_0.txt
#   inflating: aclImdb/train/unsup/5996_0.txt
#   inflating: aclImdb/train/unsup/5997_0.txt
#   inflating: aclImdb/train/unsup/5998_0.txt
#   inflating: aclImdb/train/unsup/5999_0.txt
#   inflating: aclImdb/train/unsup/599_0.txt
#   inflating: aclImdb/train/unsup/59_0.txt
#   inflating: aclImdb/train/unsup/5_0.txt
#   inflating: aclImdb/train/unsup/6000_0.txt
#   inflating: aclImdb/train/unsup/6001_0.txt
#   inflating: aclImdb/train/unsup/6002_0.txt
#   inflating: aclImdb/train/unsup/6003_0.txt
#   inflating: aclImdb/train/unsup/6004_0.txt
#   inflating: aclImdb/train/unsup/6005_0.txt
#   inflating: aclImdb/train/unsup/6006_0.txt
#   inflating: aclImdb/train/unsup/6007_0.txt
#   inflating: aclImdb/train/unsup/6008_0.txt
#   inflating: aclImdb/train/unsup/6009_0.txt
#   inflating: aclImdb/train/unsup/600_0.txt
#   inflating: aclImdb/train/unsup/6010_0.txt
#   inflating: aclImdb/train/unsup/6011_0.txt
#   inflating: aclImdb/train/unsup/6012_0.txt
#   inflating: aclImdb/train/unsup/6013_0.txt
#   inflating: aclImdb/train/unsup/6014_0.txt
#   inflating: aclImdb/train/unsup/6015_0.txt
#   inflating: aclImdb/train/unsup/6016_0.txt
#   inflating: aclImdb/train/unsup/6017_0.txt
#   inflating: aclImdb/train/unsup/6018_0.txt
#   inflating: aclImdb/train/unsup/6019_0.txt
#   inflating: aclImdb/train/unsup/601_0.txt
#   inflating: aclImdb/train/unsup/6020_0.txt
#   inflating: aclImdb/train/unsup/6021_0.txt
#   inflating: aclImdb/train/unsup/6022_0.txt
#   inflating: aclImdb/train/unsup/6023_0.txt
#   inflating: aclImdb/train/unsup/6024_0.txt
#   inflating: aclImdb/train/unsup/6025_0.txt
#   inflating: aclImdb/train/unsup/6026_0.txt
#   inflating: aclImdb/train/unsup/6027_0.txt
#   inflating: aclImdb/train/unsup/6028_0.txt
#   inflating: aclImdb/train/unsup/6029_0.txt
#   inflating: aclImdb/train/unsup/602_0.txt
#   inflating: aclImdb/train/unsup/6030_0.txt
#   inflating: aclImdb/train/unsup/6031_0.txt
#   inflating: aclImdb/train/unsup/6032_0.txt
#   inflating: aclImdb/train/unsup/6033_0.txt
#   inflating: aclImdb/train/unsup/6034_0.txt
#   inflating: aclImdb/train/unsup/6035_0.txt
#   inflating: aclImdb/train/unsup/6036_0.txt
#   inflating: aclImdb/train/unsup/6037_0.txt
#   inflating: aclImdb/train/unsup/6038_0.txt
#   inflating: aclImdb/train/unsup/6039_0.txt
#   inflating: aclImdb/train/unsup/603_0.txt
#   inflating: aclImdb/train/unsup/6040_0.txt
#   inflating: aclImdb/train/unsup/6041_0.txt
#   inflating: aclImdb/train/unsup/6042_0.txt
#   inflating: aclImdb/train/unsup/6043_0.txt
#   inflating: aclImdb/train/unsup/6044_0.txt
#   inflating: aclImdb/train/unsup/6045_0.txt
#   inflating: aclImdb/train/unsup/6046_0.txt
#   inflating: aclImdb/train/unsup/6047_0.txt
#   inflating: aclImdb/train/unsup/6048_0.txt
#   inflating: aclImdb/train/unsup/6049_0.txt
#   inflating: aclImdb/train/unsup/604_0.txt
#   inflating: aclImdb/train/unsup/6050_0.txt
#   inflating: aclImdb/train/unsup/6051_0.txt
#   inflating: aclImdb/train/unsup/6052_0.txt
#   inflating: aclImdb/train/unsup/6053_0.txt
#   inflating: aclImdb/train/unsup/6054_0.txt
#   inflating: aclImdb/train/unsup/6055_0.txt
#   inflating: aclImdb/train/unsup/6056_0.txt
#   inflating: aclImdb/train/unsup/6057_0.txt
#   inflating: aclImdb/train/unsup/6058_0.txt
#   inflating: aclImdb/train/unsup/6059_0.txt
#   inflating: aclImdb/train/unsup/605_0.txt
#   inflating: aclImdb/train/unsup/6060_0.txt
#   inflating: aclImdb/train/unsup/6061_0.txt
#   inflating: aclImdb/train/unsup/6062_0.txt
#   inflating: aclImdb/train/unsup/6063_0.txt
#   inflating: aclImdb/train/unsup/6064_0.txt
#   inflating: aclImdb/train/unsup/6065_0.txt
#   inflating: aclImdb/train/unsup/6066_0.txt
#   inflating: aclImdb/train/unsup/6067_0.txt
#   inflating: aclImdb/train/unsup/6068_0.txt
#   inflating: aclImdb/train/unsup/6069_0.txt
#   inflating: aclImdb/train/unsup/606_0.txt
#   inflating: aclImdb/train/unsup/6070_0.txt
#   inflating: aclImdb/train/unsup/6071_0.txt
#   inflating: aclImdb/train/unsup/6072_0.txt
#   inflating: aclImdb/train/unsup/6073_0.txt
#   inflating: aclImdb/train/unsup/6074_0.txt
#   inflating: aclImdb/train/unsup/6075_0.txt
#   inflating: aclImdb/train/unsup/6076_0.txt
#   inflating: aclImdb/train/unsup/6077_0.txt
#   inflating: aclImdb/train/unsup/6078_0.txt
#   inflating: aclImdb/train/unsup/6079_0.txt
#   inflating: aclImdb/train/unsup/607_0.txt
#   inflating: aclImdb/train/unsup/6080_0.txt
#   inflating: aclImdb/train/unsup/6081_0.txt
#   inflating: aclImdb/train/unsup/6082_0.txt
#   inflating: aclImdb/train/unsup/6083_0.txt
#   inflating: aclImdb/train/unsup/6084_0.txt
#   inflating: aclImdb/train/unsup/6085_0.txt
#   inflating: aclImdb/train/unsup/6086_0.txt
#   inflating: aclImdb/train/unsup/6087_0.txt
#   inflating: aclImdb/train/unsup/6088_0.txt
#   inflating: aclImdb/train/unsup/6089_0.txt
#   inflating: aclImdb/train/unsup/608_0.txt
#   inflating: aclImdb/train/unsup/6090_0.txt
#   inflating: aclImdb/train/unsup/6091_0.txt
#   inflating: aclImdb/train/unsup/6092_0.txt
#   inflating: aclImdb/train/unsup/6093_0.txt
#   inflating: aclImdb/train/unsup/6094_0.txt
#   inflating: aclImdb/train/unsup/6095_0.txt
#   inflating: aclImdb/train/unsup/6096_0.txt
#   inflating: aclImdb/train/unsup/6097_0.txt
#   inflating: aclImdb/train/unsup/6098_0.txt
#   inflating: aclImdb/train/unsup/6099_0.txt
#   inflating: aclImdb/train/unsup/609_0.txt
#   inflating: aclImdb/train/unsup/60_0.txt
#   inflating: aclImdb/train/unsup/6100_0.txt
#   inflating: aclImdb/train/unsup/6101_0.txt
#   inflating: aclImdb/train/unsup/6102_0.txt
#   inflating: aclImdb/train/unsup/6103_0.txt
#   inflating: aclImdb/train/unsup/6104_0.txt
#   inflating: aclImdb/train/unsup/6105_0.txt
#   inflating: aclImdb/train/unsup/6106_0.txt
#   inflating: aclImdb/train/unsup/6107_0.txt
#   inflating: aclImdb/train/unsup/6108_0.txt
#   inflating: aclImdb/train/unsup/6109_0.txt
#   inflating: aclImdb/train/unsup/610_0.txt
#   inflating: aclImdb/train/unsup/6110_0.txt
#   inflating: aclImdb/train/unsup/6111_0.txt
#   inflating: aclImdb/train/unsup/6112_0.txt
#   inflating: aclImdb/train/unsup/6113_0.txt
#   inflating: aclImdb/train/unsup/6114_0.txt
#   inflating: aclImdb/train/unsup/6115_0.txt
#   inflating: aclImdb/train/unsup/6116_0.txt
#   inflating: aclImdb/train/unsup/6117_0.txt
#   inflating: aclImdb/train/unsup/6118_0.txt
#   inflating: aclImdb/train/unsup/6119_0.txt
#   inflating: aclImdb/train/unsup/611_0.txt
#   inflating: aclImdb/train/unsup/6120_0.txt
#   inflating: aclImdb/train/unsup/6121_0.txt
#   inflating: aclImdb/train/unsup/6122_0.txt
#   inflating: aclImdb/train/unsup/6123_0.txt
#   inflating: aclImdb/train/unsup/6124_0.txt
#   inflating: aclImdb/train/unsup/6125_0.txt
#   inflating: aclImdb/train/unsup/6126_0.txt
#   inflating: aclImdb/train/unsup/6127_0.txt
#   inflating: aclImdb/train/unsup/6128_0.txt
#   inflating: aclImdb/train/unsup/6129_0.txt
#   inflating: aclImdb/train/unsup/612_0.txt
#   inflating: aclImdb/train/unsup/6130_0.txt
#   inflating: aclImdb/train/unsup/6131_0.txt
#   inflating: aclImdb/train/unsup/6132_0.txt
#   inflating: aclImdb/train/unsup/6133_0.txt
#   inflating: aclImdb/train/unsup/6134_0.txt
#   inflating: aclImdb/train/unsup/6135_0.txt
#   inflating: aclImdb/train/unsup/6136_0.txt
#   inflating: aclImdb/train/unsup/6137_0.txt
#   inflating: aclImdb/train/unsup/6138_0.txt
#   inflating: aclImdb/train/unsup/6139_0.txt
#   inflating: aclImdb/train/unsup/613_0.txt
#   inflating: aclImdb/train/unsup/6140_0.txt
#   inflating: aclImdb/train/unsup/6141_0.txt
#   inflating: aclImdb/train/unsup/6142_0.txt
#   inflating: aclImdb/train/unsup/6143_0.txt
#   inflating: aclImdb/train/unsup/6144_0.txt
#   inflating: aclImdb/train/unsup/6145_0.txt
#   inflating: aclImdb/train/unsup/6146_0.txt
#   inflating: aclImdb/train/unsup/6147_0.txt
#   inflating: aclImdb/train/unsup/6148_0.txt
#   inflating: aclImdb/train/unsup/6149_0.txt
#   inflating: aclImdb/train/unsup/614_0.txt
#   inflating: aclImdb/train/unsup/6150_0.txt
#   inflating: aclImdb/train/unsup/6151_0.txt
#   inflating: aclImdb/train/unsup/6152_0.txt
#   inflating: aclImdb/train/unsup/6153_0.txt
#   inflating: aclImdb/train/unsup/6154_0.txt
#   inflating: aclImdb/train/unsup/6155_0.txt
#   inflating: aclImdb/train/unsup/6156_0.txt
#   inflating: aclImdb/train/unsup/6157_0.txt
#   inflating: aclImdb/train/unsup/6158_0.txt
#   inflating: aclImdb/train/unsup/6159_0.txt
#   inflating: aclImdb/train/unsup/615_0.txt
#   inflating: aclImdb/train/unsup/6160_0.txt
#   inflating: aclImdb/train/unsup/6161_0.txt
#   inflating: aclImdb/train/unsup/6162_0.txt
#   inflating: aclImdb/train/unsup/6163_0.txt
#   inflating: aclImdb/train/unsup/6164_0.txt
#   inflating: aclImdb/train/unsup/6165_0.txt
#   inflating: aclImdb/train/unsup/6166_0.txt
#   inflating: aclImdb/train/unsup/6167_0.txt
#   inflating: aclImdb/train/unsup/6168_0.txt
#   inflating: aclImdb/train/unsup/6169_0.txt
#   inflating: aclImdb/train/unsup/616_0.txt
#   inflating: aclImdb/train/unsup/6170_0.txt
#   inflating: aclImdb/train/unsup/6171_0.txt
#   inflating: aclImdb/train/unsup/6172_0.txt
#   inflating: aclImdb/train/unsup/6173_0.txt
#   inflating: aclImdb/train/unsup/6174_0.txt
#   inflating: aclImdb/train/unsup/6175_0.txt
#   inflating: aclImdb/train/unsup/6176_0.txt
#   inflating: aclImdb/train/unsup/6177_0.txt
#   inflating: aclImdb/train/unsup/6178_0.txt
#   inflating: aclImdb/train/unsup/6179_0.txt
#   inflating: aclImdb/train/unsup/617_0.txt
#   inflating: aclImdb/train/unsup/6180_0.txt
#   inflating: aclImdb/train/unsup/6181_0.txt
#   inflating: aclImdb/train/unsup/6182_0.txt
#   inflating: aclImdb/train/unsup/6183_0.txt
#   inflating: aclImdb/train/unsup/6184_0.txt
#   inflating: aclImdb/train/unsup/6185_0.txt
#   inflating: aclImdb/train/unsup/6186_0.txt
#   inflating: aclImdb/train/unsup/6187_0.txt
#   inflating: aclImdb/train/unsup/6188_0.txt
#   inflating: aclImdb/train/unsup/6189_0.txt
#   inflating: aclImdb/train/unsup/618_0.txt
#   inflating: aclImdb/train/unsup/6190_0.txt
#   inflating: aclImdb/train/unsup/6191_0.txt
#   inflating: aclImdb/train/unsup/6192_0.txt
#   inflating: aclImdb/train/unsup/6193_0.txt
#   inflating: aclImdb/train/unsup/6194_0.txt
#   inflating: aclImdb/train/unsup/6195_0.txt
#   inflating: aclImdb/train/unsup/6196_0.txt
#   inflating: aclImdb/train/unsup/6197_0.txt
#   inflating: aclImdb/train/unsup/6198_0.txt
#   inflating: aclImdb/train/unsup/6199_0.txt
#   inflating: aclImdb/train/unsup/619_0.txt
#   inflating: aclImdb/train/unsup/61_0.txt
#   inflating: aclImdb/train/unsup/6200_0.txt
#   inflating: aclImdb/train/unsup/6201_0.txt
#   inflating: aclImdb/train/unsup/6202_0.txt
#   inflating: aclImdb/train/unsup/6203_0.txt
#   inflating: aclImdb/train/unsup/6204_0.txt
#   inflating: aclImdb/train/unsup/6205_0.txt
#   inflating: aclImdb/train/unsup/6206_0.txt
#   inflating: aclImdb/train/unsup/6207_0.txt
#   inflating: aclImdb/train/unsup/6208_0.txt
#   inflating: aclImdb/train/unsup/6209_0.txt
#   inflating: aclImdb/train/unsup/620_0.txt
#   inflating: aclImdb/train/unsup/6210_0.txt
#   inflating: aclImdb/train/unsup/6211_0.txt
#   inflating: aclImdb/train/unsup/6212_0.txt
#   inflating: aclImdb/train/unsup/6213_0.txt
#   inflating: aclImdb/train/unsup/6214_0.txt
#   inflating: aclImdb/train/unsup/6215_0.txt
#   inflating: aclImdb/train/unsup/6216_0.txt
#   inflating: aclImdb/train/unsup/6217_0.txt
#   inflating: aclImdb/train/unsup/6218_0.txt
#   inflating: aclImdb/train/unsup/6219_0.txt
#   inflating: aclImdb/train/unsup/621_0.txt
#   inflating: aclImdb/train/unsup/6220_0.txt
#   inflating: aclImdb/train/unsup/6221_0.txt
#   inflating: aclImdb/train/unsup/6222_0.txt
#   inflating: aclImdb/train/unsup/6223_0.txt
#   inflating: aclImdb/train/unsup/6224_0.txt
#   inflating: aclImdb/train/unsup/6225_0.txt
#   inflating: aclImdb/train/unsup/6226_0.txt
#   inflating: aclImdb/train/unsup/6227_0.txt
#   inflating: aclImdb/train/unsup/6228_0.txt
#   inflating: aclImdb/train/unsup/6229_0.txt
#   inflating: aclImdb/train/unsup/622_0.txt
#   inflating: aclImdb/train/unsup/6230_0.txt
#   inflating: aclImdb/train/unsup/6231_0.txt
#   inflating: aclImdb/train/unsup/6232_0.txt
#   inflating: aclImdb/train/unsup/6233_0.txt
#   inflating: aclImdb/train/unsup/6234_0.txt
#   inflating: aclImdb/train/unsup/6235_0.txt
#   inflating: aclImdb/train/unsup/6236_0.txt
#   inflating: aclImdb/train/unsup/6237_0.txt
#   inflating: aclImdb/train/unsup/6238_0.txt
#   inflating: aclImdb/train/unsup/6239_0.txt
#   inflating: aclImdb/train/unsup/623_0.txt
#   inflating: aclImdb/train/unsup/6240_0.txt
#   inflating: aclImdb/train/unsup/6241_0.txt
#   inflating: aclImdb/train/unsup/6242_0.txt
#   inflating: aclImdb/train/unsup/6243_0.txt
#   inflating: aclImdb/train/unsup/6244_0.txt
#   inflating: aclImdb/train/unsup/6245_0.txt
#   inflating: aclImdb/train/unsup/6246_0.txt
#   inflating: aclImdb/train/unsup/6247_0.txt
#   inflating: aclImdb/train/unsup/6248_0.txt
#   inflating: aclImdb/train/unsup/6249_0.txt
#   inflating: aclImdb/train/unsup/624_0.txt
#   inflating: aclImdb/train/unsup/6250_0.txt
#   inflating: aclImdb/train/unsup/6251_0.txt
#   inflating: aclImdb/train/unsup/6252_0.txt
#   inflating: aclImdb/train/unsup/6253_0.txt
#   inflating: aclImdb/train/unsup/6254_0.txt
#   inflating: aclImdb/train/unsup/6255_0.txt
#   inflating: aclImdb/train/unsup/6256_0.txt
#   inflating: aclImdb/train/unsup/6257_0.txt
#   inflating: aclImdb/train/unsup/6258_0.txt
#   inflating: aclImdb/train/unsup/6259_0.txt
#   inflating: aclImdb/train/unsup/625_0.txt
#   inflating: aclImdb/train/unsup/6260_0.txt
#   inflating: aclImdb/train/unsup/6261_0.txt
#   inflating: aclImdb/train/unsup/6262_0.txt
#   inflating: aclImdb/train/unsup/6263_0.txt
#   inflating: aclImdb/train/unsup/6264_0.txt
#   inflating: aclImdb/train/unsup/6265_0.txt
#   inflating: aclImdb/train/unsup/6266_0.txt
#   inflating: aclImdb/train/unsup/6267_0.txt
#   inflating: aclImdb/train/unsup/6268_0.txt
#   inflating: aclImdb/train/unsup/6269_0.txt
#   inflating: aclImdb/train/unsup/626_0.txt
#   inflating: aclImdb/train/unsup/6270_0.txt
#   inflating: aclImdb/train/unsup/6271_0.txt
#   inflating: aclImdb/train/unsup/6272_0.txt
#   inflating: aclImdb/train/unsup/6273_0.txt
#   inflating: aclImdb/train/unsup/6274_0.txt
#   inflating: aclImdb/train/unsup/6275_0.txt
#   inflating: aclImdb/train/unsup/6276_0.txt
#   inflating: aclImdb/train/unsup/6277_0.txt
#   inflating: aclImdb/train/unsup/6278_0.txt
#   inflating: aclImdb/train/unsup/6279_0.txt
#   inflating: aclImdb/train/unsup/627_0.txt
#   inflating: aclImdb/train/unsup/6280_0.txt
#   inflating: aclImdb/train/unsup/6281_0.txt
#   inflating: aclImdb/train/unsup/6282_0.txt
#   inflating: aclImdb/train/unsup/6283_0.txt
#   inflating: aclImdb/train/unsup/6284_0.txt
#   inflating: aclImdb/train/unsup/6285_0.txt
#   inflating: aclImdb/train/unsup/6286_0.txt
#   inflating: aclImdb/train/unsup/6287_0.txt
#   inflating: aclImdb/train/unsup/6288_0.txt
#   inflating: aclImdb/train/unsup/6289_0.txt
#   inflating: aclImdb/train/unsup/628_0.txt
#   inflating: aclImdb/train/unsup/6290_0.txt
#   inflating: aclImdb/train/unsup/6291_0.txt
#   inflating: aclImdb/train/unsup/6292_0.txt
#   inflating: aclImdb/train/unsup/6293_0.txt
#   inflating: aclImdb/train/unsup/6294_0.txt
#   inflating: aclImdb/train/unsup/6295_0.txt
#   inflating: aclImdb/train/unsup/6296_0.txt
#   inflating: aclImdb/train/unsup/6297_0.txt
#   inflating: aclImdb/train/unsup/6298_0.txt
#   inflating: aclImdb/train/unsup/6299_0.txt
#   inflating: aclImdb/train/unsup/629_0.txt
#   inflating: aclImdb/train/unsup/62_0.txt
#   inflating: aclImdb/train/unsup/6300_0.txt
#   inflating: aclImdb/train/unsup/6301_0.txt
#   inflating: aclImdb/train/unsup/6302_0.txt
#   inflating: aclImdb/train/unsup/6303_0.txt
#   inflating: aclImdb/train/unsup/6304_0.txt
#   inflating: aclImdb/train/unsup/6305_0.txt
#   inflating: aclImdb/train/unsup/6306_0.txt
#   inflating: aclImdb/train/unsup/6307_0.txt
#   inflating: aclImdb/train/unsup/6308_0.txt
#   inflating: aclImdb/train/unsup/6309_0.txt
#   inflating: aclImdb/train/unsup/630_0.txt
#   inflating: aclImdb/train/unsup/6310_0.txt
#   inflating: aclImdb/train/unsup/6311_0.txt
#   inflating: aclImdb/train/unsup/6312_0.txt
#   inflating: aclImdb/train/unsup/6313_0.txt
#   inflating: aclImdb/train/unsup/6314_0.txt
#   inflating: aclImdb/train/unsup/6315_0.txt
#   inflating: aclImdb/train/unsup/6316_0.txt
#   inflating: aclImdb/train/unsup/6317_0.txt
#   inflating: aclImdb/train/unsup/6318_0.txt
#   inflating: aclImdb/train/unsup/6319_0.txt
#   inflating: aclImdb/train/unsup/631_0.txt
#   inflating: aclImdb/train/unsup/6320_0.txt
#   inflating: aclImdb/train/unsup/6321_0.txt
#   inflating: aclImdb/train/unsup/6322_0.txt
#   inflating: aclImdb/train/unsup/6323_0.txt
#   inflating: aclImdb/train/unsup/6324_0.txt
#   inflating: aclImdb/train/unsup/6325_0.txt
#   inflating: aclImdb/train/unsup/6326_0.txt
#   inflating: aclImdb/train/unsup/6327_0.txt
#   inflating: aclImdb/train/unsup/6328_0.txt
#   inflating: aclImdb/train/unsup/6329_0.txt
#   inflating: aclImdb/train/unsup/632_0.txt
#   inflating: aclImdb/train/unsup/6330_0.txt
#   inflating: aclImdb/train/unsup/6331_0.txt
#   inflating: aclImdb/train/unsup/6332_0.txt
#   inflating: aclImdb/train/unsup/6333_0.txt
#   inflating: aclImdb/train/unsup/6334_0.txt
#   inflating: aclImdb/train/unsup/6335_0.txt
#   inflating: aclImdb/train/unsup/6336_0.txt
#   inflating: aclImdb/train/unsup/6337_0.txt
#   inflating: aclImdb/train/unsup/6338_0.txt
#   inflating: aclImdb/train/unsup/6339_0.txt
#   inflating: aclImdb/train/unsup/633_0.txt
#   inflating: aclImdb/train/unsup/6340_0.txt
#   inflating: aclImdb/train/unsup/6341_0.txt
#   inflating: aclImdb/train/unsup/6342_0.txt
#   inflating: aclImdb/train/unsup/6343_0.txt
#   inflating: aclImdb/train/unsup/6344_0.txt
#   inflating: aclImdb/train/unsup/6345_0.txt
#   inflating: aclImdb/train/unsup/6346_0.txt
#   inflating: aclImdb/train/unsup/6347_0.txt
#   inflating: aclImdb/train/unsup/6348_0.txt
#   inflating: aclImdb/train/unsup/6349_0.txt
#   inflating: aclImdb/train/unsup/634_0.txt
#   inflating: aclImdb/train/unsup/6350_0.txt
#   inflating: aclImdb/train/unsup/6351_0.txt
#   inflating: aclImdb/train/unsup/6352_0.txt
#   inflating: aclImdb/train/unsup/6353_0.txt
#   inflating: aclImdb/train/unsup/6354_0.txt
#   inflating: aclImdb/train/unsup/6355_0.txt
#   inflating: aclImdb/train/unsup/6356_0.txt
#   inflating: aclImdb/train/unsup/6357_0.txt
#   inflating: aclImdb/train/unsup/6358_0.txt
#   inflating: aclImdb/train/unsup/6359_0.txt
#   inflating: aclImdb/train/unsup/635_0.txt
#   inflating: aclImdb/train/unsup/6360_0.txt
#   inflating: aclImdb/train/unsup/6361_0.txt
#   inflating: aclImdb/train/unsup/6362_0.txt
#   inflating: aclImdb/train/unsup/6363_0.txt
#   inflating: aclImdb/train/unsup/6364_0.txt
#   inflating: aclImdb/train/unsup/6365_0.txt
#   inflating: aclImdb/train/unsup/6366_0.txt
#   inflating: aclImdb/train/unsup/6367_0.txt
#   inflating: aclImdb/train/unsup/6368_0.txt
#   inflating: aclImdb/train/unsup/6369_0.txt
#   inflating: aclImdb/train/unsup/636_0.txt
#   inflating: aclImdb/train/unsup/6370_0.txt
#   inflating: aclImdb/train/unsup/6371_0.txt
#   inflating: aclImdb/train/unsup/6372_0.txt
#   inflating: aclImdb/train/unsup/6373_0.txt
#   inflating: aclImdb/train/unsup/6374_0.txt
#   inflating: aclImdb/train/unsup/6375_0.txt
#   inflating: aclImdb/train/unsup/6376_0.txt
#   inflating: aclImdb/train/unsup/6377_0.txt
#   inflating: aclImdb/train/unsup/6378_0.txt
#   inflating: aclImdb/train/unsup/6379_0.txt
#   inflating: aclImdb/train/unsup/637_0.txt
#   inflating: aclImdb/train/unsup/6380_0.txt
#   inflating: aclImdb/train/unsup/6381_0.txt
#   inflating: aclImdb/train/unsup/6382_0.txt
#   inflating: aclImdb/train/unsup/6383_0.txt
#   inflating: aclImdb/train/unsup/6384_0.txt
#   inflating: aclImdb/train/unsup/6385_0.txt
#   inflating: aclImdb/train/unsup/6386_0.txt
#   inflating: aclImdb/train/unsup/6387_0.txt
#   inflating: aclImdb/train/unsup/6388_0.txt
#   inflating: aclImdb/train/unsup/6389_0.txt
#   inflating: aclImdb/train/unsup/638_0.txt
#   inflating: aclImdb/train/unsup/6390_0.txt
#   inflating: aclImdb/train/unsup/6391_0.txt
#   inflating: aclImdb/train/unsup/6392_0.txt
#   inflating: aclImdb/train/unsup/6393_0.txt
#   inflating: aclImdb/train/unsup/6394_0.txt
#   inflating: aclImdb/train/unsup/6395_0.txt
#   inflating: aclImdb/train/unsup/6396_0.txt
#   inflating: aclImdb/train/unsup/6397_0.txt
#   inflating: aclImdb/train/unsup/6398_0.txt
#   inflating: aclImdb/train/unsup/6399_0.txt
#   inflating: aclImdb/train/unsup/639_0.txt
#   inflating: aclImdb/train/unsup/63_0.txt
#   inflating: aclImdb/train/unsup/6400_0.txt
#   inflating: aclImdb/train/unsup/6401_0.txt
#   inflating: aclImdb/train/unsup/6402_0.txt
#   inflating: aclImdb/train/unsup/6403_0.txt
#   inflating: aclImdb/train/unsup/6404_0.txt
#   inflating: aclImdb/train/unsup/6405_0.txt
#   inflating: aclImdb/train/unsup/6406_0.txt
#   inflating: aclImdb/train/unsup/6407_0.txt
#   inflating: aclImdb/train/unsup/6408_0.txt
#   inflating: aclImdb/train/unsup/6409_0.txt
#   inflating: aclImdb/train/unsup/640_0.txt
#   inflating: aclImdb/train/unsup/6410_0.txt
#   inflating: aclImdb/train/unsup/6411_0.txt
#   inflating: aclImdb/train/unsup/6412_0.txt
#   inflating: aclImdb/train/unsup/6413_0.txt
#   inflating: aclImdb/train/unsup/6414_0.txt
#   inflating: aclImdb/train/unsup/6415_0.txt
#   inflating: aclImdb/train/unsup/6416_0.txt
#   inflating: aclImdb/train/unsup/6417_0.txt
#   inflating: aclImdb/train/unsup/6418_0.txt
#   inflating: aclImdb/train/unsup/6419_0.txt
#   inflating: aclImdb/train/unsup/641_0.txt
#   inflating: aclImdb/train/unsup/6420_0.txt
#   inflating: aclImdb/train/unsup/6421_0.txt
#   inflating: aclImdb/train/unsup/6422_0.txt
#   inflating: aclImdb/train/unsup/6423_0.txt
#   inflating: aclImdb/train/unsup/6424_0.txt
#   inflating: aclImdb/train/unsup/6425_0.txt
#   inflating: aclImdb/train/unsup/6426_0.txt
#   inflating: aclImdb/train/unsup/6427_0.txt
#   inflating: aclImdb/train/unsup/6428_0.txt
#   inflating: aclImdb/train/unsup/6429_0.txt
#   inflating: aclImdb/train/unsup/642_0.txt
#   inflating: aclImdb/train/unsup/6430_0.txt
#   inflating: aclImdb/train/unsup/6431_0.txt
#   inflating: aclImdb/train/unsup/6432_0.txt
#   inflating: aclImdb/train/unsup/6433_0.txt
#   inflating: aclImdb/train/unsup/6434_0.txt
#   inflating: aclImdb/train/unsup/6435_0.txt
#   inflating: aclImdb/train/unsup/6436_0.txt
#   inflating: aclImdb/train/unsup/6437_0.txt
#   inflating: aclImdb/train/unsup/6438_0.txt
#   inflating: aclImdb/train/unsup/6439_0.txt
#   inflating: aclImdb/train/unsup/643_0.txt
#   inflating: aclImdb/train/unsup/6440_0.txt
#   inflating: aclImdb/train/unsup/6441_0.txt
#   inflating: aclImdb/train/unsup/6442_0.txt
#   inflating: aclImdb/train/unsup/6443_0.txt
# ...
#   inflating: aclImdb/train/unsup/9691_0.txt
#   inflating: aclImdb/train/unsup/9692_0.txt
#   inflating: aclImdb/train/unsup/9693_0.txt
#   inflating: aclImdb/train/unsup/9694_0.txt
#   inflating: aclImdb/train/unsup/9695_0.txt
#   inflating: aclImdb/train/unsup/9696_0.txt
#   inflating: aclImdb/train/unsup/9697_0.txt
#   inflating: aclImdb/train/unsup/9698_0.txt
#   inflating: aclImdb/train/unsup/9699_0.txt
#   inflating: aclImdb/train/unsup/969_0.txt
#   inflating: aclImdb/train/unsup/96_0.txt
#   inflating: aclImdb/train/unsup/9700_0.txt
#   inflating: aclImdb/train/unsup/9701_0.txt
#   inflating: aclImdb/train/unsup/9702_0.txt
#   inflating: aclImdb/train/unsup/9703_0.txt
#   inflating: aclImdb/train/unsup/9704_0.txt
#   inflating: aclImdb/train/unsup/9705_0.txt
#   inflating: aclImdb/train/unsup/9706_0.txt
#   inflating: aclImdb/train/unsup/9707_0.txt
#   inflating: aclImdb/train/unsup/9708_0.txt
#   inflating: aclImdb/train/unsup/9709_0.txt
#   inflating: aclImdb/train/unsup/970_0.txt
#   inflating: aclImdb/train/unsup/9710_0.txt
#   inflating: aclImdb/train/unsup/9711_0.txt
#   inflating: aclImdb/train/unsup/9712_0.txt
#   inflating: aclImdb/train/unsup/9713_0.txt
#   inflating: aclImdb/train/unsup/9714_0.txt
#   inflating: aclImdb/train/unsup/9715_0.txt
#   inflating: aclImdb/train/unsup/9716_0.txt
#   inflating: aclImdb/train/unsup/9717_0.txt
#   inflating: aclImdb/train/unsup/9718_0.txt
#   inflating: aclImdb/train/unsup/9719_0.txt
#   inflating: aclImdb/train/unsup/971_0.txt
#   inflating: aclImdb/train/unsup/9720_0.txt
#   inflating: aclImdb/train/unsup/9721_0.txt
#   inflating: aclImdb/train/unsup/9722_0.txt
#   inflating: aclImdb/train/unsup/9723_0.txt
#   inflating: aclImdb/train/unsup/9724_0.txt
#   inflating: aclImdb/train/unsup/9725_0.txt
#   inflating: aclImdb/train/unsup/9726_0.txt
#   inflating: aclImdb/train/unsup/9727_0.txt
#   inflating: aclImdb/train/unsup/9728_0.txt
#   inflating: aclImdb/train/unsup/9729_0.txt
#   inflating: aclImdb/train/unsup/972_0.txt
#   inflating: aclImdb/train/unsup/9730_0.txt
#   inflating: aclImdb/train/unsup/9731_0.txt
#   inflating: aclImdb/train/unsup/9732_0.txt
#   inflating: aclImdb/train/unsup/9733_0.txt
#   inflating: aclImdb/train/unsup/9734_0.txt
#   inflating: aclImdb/train/unsup/9735_0.txt
#   inflating: aclImdb/train/unsup/9736_0.txt
#   inflating: aclImdb/train/unsup/9737_0.txt
#   inflating: aclImdb/train/unsup/9738_0.txt
#   inflating: aclImdb/train/unsup/9739_0.txt
#   inflating: aclImdb/train/unsup/973_0.txt
#   inflating: aclImdb/train/unsup/9740_0.txt
#   inflating: aclImdb/train/unsup/9741_0.txt
#   inflating: aclImdb/train/unsup/9742_0.txt
#   inflating: aclImdb/train/unsup/9743_0.txt
#   inflating: aclImdb/train/unsup/9744_0.txt
#   inflating: aclImdb/train/unsup/9745_0.txt
#   inflating: aclImdb/train/unsup/9746_0.txt
#   inflating: aclImdb/train/unsup/9747_0.txt
#   inflating: aclImdb/train/unsup/9748_0.txt
#   inflating: aclImdb/train/unsup/9749_0.txt
#   inflating: aclImdb/train/unsup/974_0.txt
#   inflating: aclImdb/train/unsup/9750_0.txt
#   inflating: aclImdb/train/unsup/9751_0.txt
#   inflating: aclImdb/train/unsup/9752_0.txt
#   inflating: aclImdb/train/unsup/9753_0.txt
#   inflating: aclImdb/train/unsup/9754_0.txt
#   inflating: aclImdb/train/unsup/9755_0.txt
#   inflating: aclImdb/train/unsup/9756_0.txt
#   inflating: aclImdb/train/unsup/9757_0.txt
#   inflating: aclImdb/train/unsup/9758_0.txt
#   inflating: aclImdb/train/unsup/9759_0.txt
#   inflating: aclImdb/train/unsup/975_0.txt
#   inflating: aclImdb/train/unsup/9760_0.txt
#   inflating: aclImdb/train/unsup/9761_0.txt
#   inflating: aclImdb/train/unsup/9762_0.txt
#   inflating: aclImdb/train/unsup/9763_0.txt
#   inflating: aclImdb/train/unsup/9764_0.txt
#   inflating: aclImdb/train/unsup/9765_0.txt
#   inflating: aclImdb/train/unsup/9766_0.txt
#   inflating: aclImdb/train/unsup/9767_0.txt
#   inflating: aclImdb/train/unsup/9768_0.txt
#   inflating: aclImdb/train/unsup/9769_0.txt
#   inflating: aclImdb/train/unsup/976_0.txt
#   inflating: aclImdb/train/unsup/9770_0.txt
#   inflating: aclImdb/train/unsup/9771_0.txt
#   inflating: aclImdb/train/unsup/9772_0.txt
#   inflating: aclImdb/train/unsup/9773_0.txt
#   inflating: aclImdb/train/unsup/9774_0.txt
#   inflating: aclImdb/train/unsup/9775_0.txt
#   inflating: aclImdb/train/unsup/9776_0.txt
#   inflating: aclImdb/train/unsup/9777_0.txt
#   inflating: aclImdb/train/unsup/9778_0.txt
#   inflating: aclImdb/train/unsup/9779_0.txt
#   inflating: aclImdb/train/unsup/977_0.txt
#   inflating: aclImdb/train/unsup/9780_0.txt
#   inflating: aclImdb/train/unsup/9781_0.txt
#   inflating: aclImdb/train/unsup/9782_0.txt
#   inflating: aclImdb/train/unsup/9783_0.txt
#   inflating: aclImdb/train/unsup/9784_0.txt
#   inflating: aclImdb/train/unsup/9785_0.txt
#   inflating: aclImdb/train/unsup/9786_0.txt
#   inflating: aclImdb/train/unsup/9787_0.txt
#   inflating: aclImdb/train/unsup/9788_0.txt
#   inflating: aclImdb/train/unsup/9789_0.txt
#   inflating: aclImdb/train/unsup/978_0.txt
#   inflating: aclImdb/train/unsup/9790_0.txt
#   inflating: aclImdb/train/unsup/9791_0.txt
#   inflating: aclImdb/train/unsup/9792_0.txt
#   inflating: aclImdb/train/unsup/9793_0.txt
#   inflating: aclImdb/train/unsup/9794_0.txt
#   inflating: aclImdb/train/unsup/9795_0.txt
#   inflating: aclImdb/train/unsup/9796_0.txt
#   inflating: aclImdb/train/unsup/9797_0.txt
#   inflating: aclImdb/train/unsup/9798_0.txt
#   inflating: aclImdb/train/unsup/9799_0.txt
#   inflating: aclImdb/train/unsup/979_0.txt
#   inflating: aclImdb/train/unsup/97_0.txt
#   inflating: aclImdb/train/unsup/9800_0.txt
#   inflating: aclImdb/train/unsup/9801_0.txt
#   inflating: aclImdb/train/unsup/9802_0.txt
#   inflating: aclImdb/train/unsup/9803_0.txt
#   inflating: aclImdb/train/unsup/9804_0.txt
#   inflating: aclImdb/train/unsup/9805_0.txt
#   inflating: aclImdb/train/unsup/9806_0.txt
#   inflating: aclImdb/train/unsup/9807_0.txt
#   inflating: aclImdb/train/unsup/9808_0.txt
#   inflating: aclImdb/train/unsup/9809_0.txt
#   inflating: aclImdb/train/unsup/980_0.txt
#   inflating: aclImdb/train/unsup/9810_0.txt
#   inflating: aclImdb/train/unsup/9811_0.txt
#   inflating: aclImdb/train/unsup/9812_0.txt
#   inflating: aclImdb/train/unsup/9813_0.txt
#   inflating: aclImdb/train/unsup/9814_0.txt
#   inflating: aclImdb/train/unsup/9815_0.txt
#   inflating: aclImdb/train/unsup/9816_0.txt
#   inflating: aclImdb/train/unsup/9817_0.txt
#   inflating: aclImdb/train/unsup/9818_0.txt
#   inflating: aclImdb/train/unsup/9819_0.txt
#   inflating: aclImdb/train/unsup/981_0.txt
#   inflating: aclImdb/train/unsup/9820_0.txt
#   inflating: aclImdb/train/unsup/9821_0.txt
#   inflating: aclImdb/train/unsup/9822_0.txt
#   inflating: aclImdb/train/unsup/9823_0.txt
#   inflating: aclImdb/train/unsup/9824_0.txt
#   inflating: aclImdb/train/unsup/9825_0.txt
#   inflating: aclImdb/train/unsup/9826_0.txt
#   inflating: aclImdb/train/unsup/9827_0.txt
#   inflating: aclImdb/train/unsup/9828_0.txt
#   inflating: aclImdb/train/unsup/9829_0.txt
#   inflating: aclImdb/train/unsup/982_0.txt
#   inflating: aclImdb/train/unsup/9830_0.txt
#   inflating: aclImdb/train/unsup/9831_0.txt
#   inflating: aclImdb/train/unsup/9832_0.txt
#   inflating: aclImdb/train/unsup/9833_0.txt
#   inflating: aclImdb/train/unsup/9834_0.txt
#   inflating: aclImdb/train/unsup/9835_0.txt
#   inflating: aclImdb/train/unsup/9836_0.txt
#   inflating: aclImdb/train/unsup/9837_0.txt
#   inflating: aclImdb/train/unsup/9838_0.txt
#   inflating: aclImdb/train/unsup/9839_0.txt
#   inflating: aclImdb/train/unsup/983_0.txt
#   inflating: aclImdb/train/unsup/9840_0.txt
#   inflating: aclImdb/train/unsup/9841_0.txt
#   inflating: aclImdb/train/unsup/9842_0.txt
#   inflating: aclImdb/train/unsup/9843_0.txt
#   inflating: aclImdb/train/unsup/9844_0.txt
#   inflating: aclImdb/train/unsup/9845_0.txt
#   inflating: aclImdb/train/unsup/9846_0.txt
#   inflating: aclImdb/train/unsup/9847_0.txt
#   inflating: aclImdb/train/unsup/9848_0.txt
#   inflating: aclImdb/train/unsup/9849_0.txt
#   inflating: aclImdb/train/unsup/984_0.txt
#   inflating: aclImdb/train/unsup/9850_0.txt
#   inflating: aclImdb/train/unsup/9851_0.txt
#   inflating: aclImdb/train/unsup/9852_0.txt
#   inflating: aclImdb/train/unsup/9853_0.txt
#   inflating: aclImdb/train/unsup/9854_0.txt
#   inflating: aclImdb/train/unsup/9855_0.txt
#   inflating: aclImdb/train/unsup/9856_0.txt
#   inflating: aclImdb/train/unsup/9857_0.txt
#   inflating: aclImdb/train/unsup/9858_0.txt
#   inflating: aclImdb/train/unsup/9859_0.txt
#   inflating: aclImdb/train/unsup/985_0.txt
#   inflating: aclImdb/train/unsup/9860_0.txt
#   inflating: aclImdb/train/unsup/9861_0.txt
#   inflating: aclImdb/train/unsup/9862_0.txt
#   inflating: aclImdb/train/unsup/9863_0.txt
#   inflating: aclImdb/train/unsup/9864_0.txt
#   inflating: aclImdb/train/unsup/9865_0.txt
#   inflating: aclImdb/train/unsup/9866_0.txt
#   inflating: aclImdb/train/unsup/9867_0.txt
#   inflating: aclImdb/train/unsup/9868_0.txt
#   inflating: aclImdb/train/unsup/9869_0.txt
#   inflating: aclImdb/train/unsup/986_0.txt
#   inflating: aclImdb/train/unsup/9870_0.txt
#   inflating: aclImdb/train/unsup/9871_0.txt
#   inflating: aclImdb/train/unsup/9872_0.txt
#   inflating: aclImdb/train/unsup/9873_0.txt
#   inflating: aclImdb/train/unsup/9874_0.txt
#   inflating: aclImdb/train/unsup/9875_0.txt
#   inflating: aclImdb/train/unsup/9876_0.txt
#   inflating: aclImdb/train/unsup/9877_0.txt
#   inflating: aclImdb/train/unsup/9878_0.txt
#   inflating: aclImdb/train/unsup/9879_0.txt
#   inflating: aclImdb/train/unsup/987_0.txt
#   inflating: aclImdb/train/unsup/9880_0.txt
#   inflating: aclImdb/train/unsup/9881_0.txt
#   inflating: aclImdb/train/unsup/9882_0.txt
#   inflating: aclImdb/train/unsup/9883_0.txt
#   inflating: aclImdb/train/unsup/9884_0.txt
#   inflating: aclImdb/train/unsup/9885_0.txt
#   inflating: aclImdb/train/unsup/9886_0.txt
#   inflating: aclImdb/train/unsup/9887_0.txt
#   inflating: aclImdb/train/unsup/9888_0.txt
#   inflating: aclImdb/train/unsup/9889_0.txt
#   inflating: aclImdb/train/unsup/988_0.txt
#   inflating: aclImdb/train/unsup/9890_0.txt
#   inflating: aclImdb/train/unsup/9891_0.txt
#   inflating: aclImdb/train/unsup/9892_0.txt
#   inflating: aclImdb/train/unsup/9893_0.txt
#   inflating: aclImdb/train/unsup/9894_0.txt
#   inflating: aclImdb/train/unsup/9895_0.txt
#   inflating: aclImdb/train/unsup/9896_0.txt
#   inflating: aclImdb/train/unsup/9897_0.txt
#   inflating: aclImdb/train/unsup/9898_0.txt
#   inflating: aclImdb/train/unsup/9899_0.txt
#   inflating: aclImdb/train/unsup/989_0.txt
#   inflating: aclImdb/train/unsup/98_0.txt
#   inflating: aclImdb/train/unsup/9900_0.txt
#   inflating: aclImdb/train/unsup/9901_0.txt
#   inflating: aclImdb/train/unsup/9902_0.txt
#   inflating: aclImdb/train/unsup/9903_0.txt
#   inflating: aclImdb/train/unsup/9904_0.txt
#   inflating: aclImdb/train/unsup/9905_0.txt
#   inflating: aclImdb/train/unsup/9906_0.txt
#   inflating: aclImdb/train/unsup/9907_0.txt
#   inflating: aclImdb/train/unsup/9908_0.txt
#   inflating: aclImdb/train/unsup/9909_0.txt
#   inflating: aclImdb/train/unsup/990_0.txt
#   inflating: aclImdb/train/unsup/9910_0.txt
#   inflating: aclImdb/train/unsup/9911_0.txt
#   inflating: aclImdb/train/unsup/9912_0.txt
#   inflating: aclImdb/train/unsup/9913_0.txt
#   inflating: aclImdb/train/unsup/9914_0.txt
#   inflating: aclImdb/train/unsup/9915_0.txt
#   inflating: aclImdb/train/unsup/9916_0.txt
#   inflating: aclImdb/train/unsup/9917_0.txt
#   inflating: aclImdb/train/unsup/9918_0.txt
#   inflating: aclImdb/train/unsup/9919_0.txt
#   inflating: aclImdb/train/unsup/991_0.txt
#   inflating: aclImdb/train/unsup/9920_0.txt
#   inflating: aclImdb/train/unsup/9921_0.txt
#   inflating: aclImdb/train/unsup/9922_0.txt
#   inflating: aclImdb/train/unsup/9923_0.txt
#   inflating: aclImdb/train/unsup/9924_0.txt
#   inflating: aclImdb/train/unsup/9925_0.txt
#   inflating: aclImdb/train/unsup/9926_0.txt
#   inflating: aclImdb/train/unsup/9927_0.txt
#   inflating: aclImdb/train/unsup/9928_0.txt
#   inflating: aclImdb/train/unsup/9929_0.txt
#   inflating: aclImdb/train/unsup/992_0.txt
#   inflating: aclImdb/train/unsup/9930_0.txt
#   inflating: aclImdb/train/unsup/9931_0.txt
#   inflating: aclImdb/train/unsup/9932_0.txt
#   inflating: aclImdb/train/unsup/9933_0.txt
#   inflating: aclImdb/train/unsup/9934_0.txt
#   inflating: aclImdb/train/unsup/9935_0.txt
#   inflating: aclImdb/train/unsup/9936_0.txt
#   inflating: aclImdb/train/unsup/9937_0.txt
#   inflating: aclImdb/train/unsup/9938_0.txt
#   inflating: aclImdb/train/unsup/9939_0.txt
#   inflating: aclImdb/train/unsup/993_0.txt
#   inflating: aclImdb/train/unsup/9940_0.txt
#   inflating: aclImdb/train/unsup/9941_0.txt
#   inflating: aclImdb/train/unsup/9942_0.txt
#   inflating: aclImdb/train/unsup/9943_0.txt
#   inflating: aclImdb/train/unsup/9944_0.txt
#   inflating: aclImdb/train/unsup/9945_0.txt
#   inflating: aclImdb/train/unsup/9946_0.txt
#   inflating: aclImdb/train/unsup/9947_0.txt
#   inflating: aclImdb/train/unsup/9948_0.txt
#   inflating: aclImdb/train/unsup/9949_0.txt
#   inflating: aclImdb/train/unsup/994_0.txt
#   inflating: aclImdb/train/unsup/9950_0.txt
#   inflating: aclImdb/train/unsup/9951_0.txt
#   inflating: aclImdb/train/unsup/9952_0.txt
#   inflating: aclImdb/train/unsup/9953_0.txt
#   inflating: aclImdb/train/unsup/9954_0.txt
#   inflating: aclImdb/train/unsup/9955_0.txt
#   inflating: aclImdb/train/unsup/9956_0.txt
#   inflating: aclImdb/train/unsup/9957_0.txt
#   inflating: aclImdb/train/unsup/9958_0.txt
#   inflating: aclImdb/train/unsup/9959_0.txt
#   inflating: aclImdb/train/unsup/995_0.txt
#   inflating: aclImdb/train/unsup/9960_0.txt
#   inflating: aclImdb/train/unsup/9961_0.txt
#   inflating: aclImdb/train/unsup/9962_0.txt
#   inflating: aclImdb/train/unsup/9963_0.txt
#   inflating: aclImdb/train/unsup/9964_0.txt
#   inflating: aclImdb/train/unsup/9965_0.txt
#   inflating: aclImdb/train/unsup/9966_0.txt
#   inflating: aclImdb/train/unsup/9967_0.txt
#   inflating: aclImdb/train/unsup/9968_0.txt
#   inflating: aclImdb/train/unsup/9969_0.txt
#   inflating: aclImdb/train/unsup/996_0.txt
#   inflating: aclImdb/train/unsup/9970_0.txt
#   inflating: aclImdb/train/unsup/9971_0.txt
#   inflating: aclImdb/train/unsup/9972_0.txt
#   inflating: aclImdb/train/unsup/9973_0.txt
#   inflating: aclImdb/train/unsup/9974_0.txt
#   inflating: aclImdb/train/unsup/9975_0.txt
#   inflating: aclImdb/train/unsup/9976_0.txt
#   inflating: aclImdb/train/unsup/9977_0.txt
#   inflating: aclImdb/train/unsup/9978_0.txt
#   inflating: aclImdb/train/unsup/9979_0.txt
#   inflating: aclImdb/train/unsup/997_0.txt
#   inflating: aclImdb/train/unsup/9980_0.txt
#   inflating: aclImdb/train/unsup/9981_0.txt
#   inflating: aclImdb/train/unsup/9982_0.txt
#   inflating: aclImdb/train/unsup/9983_0.txt
#   inflating: aclImdb/train/unsup/9984_0.txt
#   inflating: aclImdb/train/unsup/9985_0.txt
#   inflating: aclImdb/train/unsup/9986_0.txt
#   inflating: aclImdb/train/unsup/9987_0.txt
#   inflating: aclImdb/train/unsup/9988_0.txt
#   inflating: aclImdb/train/unsup/9989_0.txt
#   inflating: aclImdb/train/unsup/998_0.txt
#   inflating: aclImdb/train/unsup/9990_0.txt
#   inflating: aclImdb/train/unsup/9991_0.txt
#   inflating: aclImdb/train/unsup/9992_0.txt
#   inflating: aclImdb/train/unsup/9993_0.txt
#   inflating: aclImdb/train/unsup/9994_0.txt
#   inflating: aclImdb/train/unsup/9995_0.txt
#   inflating: aclImdb/train/unsup/9996_0.txt
#   inflating: aclImdb/train/unsup/9997_0.txt
#   inflating: aclImdb/train/unsup/9998_0.txt
#   inflating: aclImdb/train/unsup/9999_0.txt
#   inflating: aclImdb/train/unsup/999_0.txt
#   inflating: aclImdb/train/unsup/99_0.txt
#   inflating: aclImdb/train/unsup/9_0.txt
#   inflating: aclImdb/train/unsupBow.feat
#   inflating: aclImdb/train/urls_neg.txt
#   inflating: aclImdb/train/urls_pos.txt
#   inflating: aclImdb/train/urls_unsup.txt

# %% [markdown]
# # **Install Required Libraries**

# %%
# !pip install -U spacy                          # To import spacy library
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.7)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.9.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.4)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.1.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)

# %%
# !python -m spacy download en                   # en contains the language-specific code and rules included in the library
# Out:
# 2022-09-25 18:25:42.497011: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.0/en_core_web_sm-3.4.0-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 8.1 MB/s
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-sm==3.4.0) (3.4.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.10.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.9.2)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.1.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.6.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (4.64.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (8.1.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2022.6.15)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (0.7.8)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install tensorflow-text                   # Provides a collection of text related classes and ops ready to use
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-text
#   Downloading tensorflow_text-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 6.0 MB/s
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-text) (0.12.0)
# Collecting tensorflow<2.11,>=2.10.0
#   Downloading tensorflow-2.10.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      |████████████████████████████████| 578.0 MB 11 kB/s
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (21.3)
# Collecting keras<2.11,>=2.10.0
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 21.6 MB/s
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (14.0.6)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.11,>=2.10.0
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 69.7 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.1.0)
# Collecting tensorboard<2.11,>=2.10
#   Downloading tensorboard-2.10.0-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 39.9 MB/s
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.48.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.15.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.21.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (4.1.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (0.26.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow-text) (2.0.7)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<2.11,>=2.10.0->tensorflow-text) (3.0.9)
# Installing collected packages: tensorflow-estimator, tensorboard, keras, gast, tensorflow, tensorflow-text
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
# Successfully installed gast-0.4.0 keras-2.10.0 tensorboard-2.10.0 tensorflow-2.10.0 tensorflow-estimator-2.10.0 tensorflow-text-2.10.0

# %%
# !pip install --upgrade tensorflow_hub          # A repository of trained machine learning models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.7/dist-packages (0.12.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_hub) (1.21.6)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_hub) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow_hub) (1.15.0)

# %%
# !pip install transformers                      # Provides APIs to quickly download and use those pretrained models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.22.1-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 8.3 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.9.0
#   Downloading huggingface_hub-0.9.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 57.3 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 35.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.9.1 tokenizers-0.12.1 transformers-4.22.1

# %%
# !python -m pip install tensorflow_text         # Provides a collection of text related classes and ops ready to use with TensorFlow 2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_text in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: tensorflow<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (2.10.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.0.7)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.26.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (4.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.1.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.17.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.15.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (1.48.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (21.3)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.11,>=2.10.0->tensorflow_text) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.5.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow<2.11,>=2.10.0->tensorflow_text) (3.0.9)

# %%
# !pip install -q -U "tensorflow-text==2.8.*"    # To install specifically 2.8 version of Tensorflow_text
# Out:
#      |████████████████████████████████| 4.9 MB 8.9 MB/s
#      |████████████████████████████████| 497.9 MB 25 kB/s
#      |████████████████████████████████| 5.8 MB 37.1 MB/s
#      |████████████████████████████████| 462 kB 42.5 MB/s
#      |████████████████████████████████| 1.4 MB 46.1 MB/s

# %%
# !pip install -q -U tf-models-official==2.7.0    # A TensorFlow Model is a Neural Network with one or more Layers
# Out:
#      |████████████████████████████████| 1.8 MB 6.8 MB/s
#      |████████████████████████████████| 238 kB 55.1 MB/s
#      |████████████████████████████████| 43 kB 1.7 MB/s
#      |████████████████████████████████| 99 kB 7.3 MB/s
#      |████████████████████████████████| 1.1 MB 50.0 MB/s
#      |████████████████████████████████| 116 kB 59.5 MB/s
#      |████████████████████████████████| 1.3 MB 65.4 MB/s
#      |████████████████████████████████| 352 kB 41.8 MB/s
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done

# %%
# !pip install -U tfds-nightly                    # A library of datasets ready to use with TensorFlow.
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tfds-nightly
#   Downloading tfds_nightly-4.6.0.dev202209250045-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 7.6 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (1.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (4.64.1)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (0.7.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (1.10.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (0.10.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (0.3.5.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (5.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (1.21.6)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (1.1.0)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (3.17.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from tfds-nightly) (4.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tfds-nightly) (2022.6.15)
# Requirement already satisfied: zipp in /usr/local/lib/python3.7/dist-packages (from etils[epath]->tfds-nightly) (3.8.1)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tfds-nightly) (1.56.4)
# Installing collected packages: tfds-nightly
# Successfully installed tfds-nightly-4.6.0.dev202209250045

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd    # Widely used for data science/data analysis and machine learning tasks
import numpy as np     # Aims to provide an array object that is up to 50x faster than traditional Python lists.
import os, glob        # Used to return all file paths that match a specific pattern
import os, os.path     # For merging, normalizing and retrieving path names in python
import seaborn as sns  # Seaborn helps you explore and understand your data

# %% [markdown]
# ### **Check, did the drive connect successfully?**

# %% [markdown]
# Before starting, we will check that our data can be read easily or if there is any error.

# %%
DIR = '/content/aclImdb/train/unsup'
print(len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))]))
# Out:
# 50000

# %% [markdown]
# Output shows that there are 50000 files in the unsup folder. That means our dataset can be readable and drive is connected successfully and there are not any issues with file path or anything else.

# %% [markdown]
# # **Procedure/Scenario**

# %% [markdown]
# Basically, all the files (which are provided to us) are in text form and are present in different folders. The core dataset contains 25,000 (positive + negative) files are for training, another 25,000 (positive + negative) files are for testing purposes, and the remaining 50,000 are for unsupervised learning.
#
# The requirement is that the size of the dataset for training should be 5000 rows and the size of the testing dataset should be 500 rows. So we'll make dataframes out of data files. We'll take 2500 positive files and 2500 negative files, label them (pos =1 and neg =0), and merge them into a single dataframe to get a labelled dataframe with 5000 rows, which will be our training dataset, and the same procedure for testing dataset.
#
# In the last step, we will train a selector transformer on a training dataset and for testing we will use a testing dataset. After that, we will evaluate the transformer by taking different values of epochs.

# %% [markdown]
# # **Prepration of Training Data**

# %% [markdown]
# As our training dataset will consist of both positive and negative labelled data, we will first take 2500 positive labelled data and then take 2500 negative labelled data and perform preprocessing on them.

# %% [markdown]
# ### **Positive Training Dataset**

# %% [markdown]
# Here we store the path of our positive training data in a variable and initialise a list named of files.

# %%
# Define relative path to folder containing the text files

files_folder = "/content/aclImdb/train/pos"
files = []

# %% [markdown]
# Now, by iterating a for loop, we extrect our (.txt format) filed data using the glob function and store it in the list in the form of a dataframe for each file data and name the column as 'text'.

# %%
# Create a dataframe list by using a list comprehension

files = [pd.read_csv(file, delimiter='\t', names =['text'] ) for file in glob.glob(os.path.join(files_folder ,"*.txt"))]

# %% [markdown]
# Here we will combine the whole list of dataframes and make a single dataframe.

# %%
# Concatenate the list of DataFrames into one
df_pos = pd.concat(files)

# %% [markdown]
# As the upper dataframe belongs to the positive class, we assigned it the label '1'. For this, we first made an array with a size of 12500 and then assigned it to the dataframe.

# %%
b = np.ones(12500, dtype = int)

df_pos = df_pos.assign(label=b)
df_pos.head()
# Out:
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1

# %% [markdown]
# Here we computed the total number of rows and columns just to show the characteristics of the dataframe.

# %%
# computing number of rows
rows = len(df_pos.axes[0])
 
# computing number of columns
cols = len(df_pos.axes[1])
 
# Simply print them
print('\n')
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
df_pos.head()
# Out:
# Number of Rows:  12500
# Number of Columns:  2
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1

# %% [markdown]
# As we know, we want a total of only 5000 (2500 pos + 2500 neg) rows for our training dataset, so, we split our dataframe and make a new dataframe which has a size of (2500,2).

# %%
# splitting dataframe by row index

df_positive = df_pos.iloc[:2500,:]
print("Shape of new dataframes - {}".format(df_positive.shape))
df_positive
# Out:
# Shape of new dataframes - (2500, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      1
# 0   I've seen this film literally over 100 times.....      1
# 0   It seems to be a perfect day for swimming. A n...      1
# 0   For fans of Troma or the Cyberpunk genre mixed...      1
# 0   This is a refreshing, enjoyable movie. If you ...      1
# ..                                                ...    ...
# 0   First things first, the female lead is too gor...      1
# 0   As a baseball die-hard, this movie goes contra...      1
# 0   This movie really rocks! Jeff Wincott is terri...      1
# 0   This is an EXCELLENT example of early Bette Da...      1
# 0   Episode two of season one is a delightful holi...      1
#
# [2500 rows x 2 columns]

# %% [markdown]
# ### **Negative Training Dataset**

# %% [markdown]
# Now the above same factors are for the preparation of the negative dataset. we store the path of our negative training data in a variable and initialise a list named of files.

# %%
# Define relative path to folder containing the text files

files_folder = "/content/aclImdb/train/neg"
files = []

# %% [markdown]
# Now, by iterating a for loop, we extrect our (.txt format) filed data using the glob function and store it in the list in the form of a dataframe for each file data and name the column as text.

# %%
# Create a dataframe list by using a list comprehension

files = [pd.read_csv(file, delimiter='\t', names =['text'] ) for file in glob.glob(os.path.join(files_folder ,"*.txt"))]

# %% [markdown]
# Here we will combine the whole list of dataframes and make a single dataframe.

# %%
# Concatenate the list of DataFrames into one

df_neg = pd.concat(files)

# %% [markdown]
# As the upper dataframe belongs to the negative class, we assigned it the label '0'. For this, we first made an array with a size of 12500 and then assigned it to the dataframe.

# %%
b = [0] * 12500

df_neg = df_pos.assign(label=b)
df_neg.head()
# Out:
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      0
# 0  I've seen this film literally over 100 times.....      0
# 0  It seems to be a perfect day for swimming. A n...      0
# 0  For fans of Troma or the Cyberpunk genre mixed...      0
# 0  This is a refreshing, enjoyable movie. If you ...      0

# %% [markdown]
# Here we computed the total number of rows and columns just to show the characteristics of the neagtive labeled dataframe.

# %%
# computing number of rows
rows = len(df_neg.axes[0])
 
# computing number of columns
cols = len(df_neg.axes[1])

# Simply print

print('\n')
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
df_neg.head()
# Out:
# Number of Rows:  12500
# Number of Columns:  2
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      0
# 0  I've seen this film literally over 100 times.....      0
# 0  It seems to be a perfect day for swimming. A n...      0
# 0  For fans of Troma or the Cyberpunk genre mixed...      0
# 0  This is a refreshing, enjoyable movie. If you ...      0

# %% [markdown]
# As we know, we want a total of only 5000 (2500 pos + 2500 neg) rows for our training dataset, so, we split our dataframe by using iloc and make a new dataframe which has a size of (2500,2).

# %%
# splitting dataframe by row index

df_negative = df_neg.iloc[:2500,:]
print("Shape of new dataframes - {}".format(df_negative.shape))
df_negative
# Out:
# Shape of new dataframes - (2500, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      0
# 0   I've seen this film literally over 100 times.....      0
# 0   It seems to be a perfect day for swimming. A n...      0
# 0   For fans of Troma or the Cyberpunk genre mixed...      0
# 0   This is a refreshing, enjoyable movie. If you ...      0
# ..                                                ...    ...
# 0   First things first, the female lead is too gor...      0
# 0   As a baseball die-hard, this movie goes contra...      0
# 0   This movie really rocks! Jeff Wincott is terri...      0
# 0   This is an EXCELLENT example of early Bette Da...      0
# 0   Episode two of season one is a delightful holi...      0
#
# [2500 rows x 2 columns]

# %% [markdown]
# ### **Combines Both datasets**

# %% [markdown]
# Now we have our positive and negative labelled dataframes, so we will merge them into a single dataframe by using the concat function of the pandas library. Then in the results we will get our training dataset size of (5000,2).

# %%
frames = [df_positive, df_negative]
  
train = pd.concat(frames)
print("Shape of new train dataframe - {}".format(train.shape))
display(train)
# Out:
# Shape of new train dataframe - (5000, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      1
# 0   I've seen this film literally over 100 times.....      1
# 0   It seems to be a perfect day for swimming. A n...      1
# 0   For fans of Troma or the Cyberpunk genre mixed...      1
# 0   This is a refreshing, enjoyable movie. If you ...      1
# ..                                                ...    ...
# 0   First things first, the female lead is too gor...      0
# 0   As a baseball die-hard, this movie goes contra...      0
# 0   This movie really rocks! Jeff Wincott is terri...      0
# 0   This is an EXCELLENT example of early Bette Da...      0
# 0   Episode two of season one is a delightful holi...      0
#
# [5000 rows x 2 columns]

# %% [markdown]
# ### **Preprocessing on Training Dataset**

# %% [markdown]
# For text processing first we import spacy library because spacy is designed specifically for production use and helps you build applications that process and “understand” large volumes of text.

# %%
import spacy

# %% [markdown]
# Now, by using spacy, we load "en_core_web_sm", which is a small English pipeline trained on written web text that includes vocabulary, syntax, and entities.
#
# Then we make a new column named "tokens" in our training dataset in which we store our text data after tokenization.

# %%
nlp = spacy.load("en_core_web_sm")
train1 = train.copy()
train1["tokens"] = train["text"].apply(lambda x: nlp.tokenizer(x))

train1.head()
# Out:
#                                                 text  label  \
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1
#
#                                               tokens
# 0  (Unfortunately, for, myself, -, I, stumbled, o...
# 0  (I, 've, seen, this, film, literally, over, 10...
# 0  (It, seems, to, be, a, perfect, day, for, swim...
# 0  (For, fans, of, Troma, or, the, Cyberpunk, gen...
# 0  (This, is, a, refreshing, ,, enjoyable, movie,...

# %% [markdown]
# Here we create a new column named "num_tokens", store the sum of tokens in each document, and make a histogram by using the seaborn library to visualise the total number of tokens per movie review.

# %%
# Sum the number of tokens in each Doc

train1['num_tokens'] = [len(token) for token in train1.tokens]

# Visualize histogram of tokens per movie review

g = sns.distplot(train1.num_tokens)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Here we have written three functions:
# 1. First is for making a spacy document in which we will join the words into a string.
# 2. In the second function, we are actually filtering the tokens in such a way that it will skip stopwords and only pick the non_stopwords tokens. Basically, we are removing stopwords.
# 3. The third one is for lemmatization, which we use . For each token, use lemma_keyword (access each token with a for loop).

# %%
def to_doc(words:tuple) -> spacy.tokens.Doc:
    # Create SpaCy documents by joining the words into a string
    return nlp(' '.join(words))

def remove_stops(doc) -> list:
    # Filter out stop words by using the `token.is_stop` attribute
    return [token.text for token in doc if not token.is_stop]

def lemmatize(doc) -> list:
    # Take the `token.lemma_` of each non-stop word
    return [token.lemma_ for token in doc if not token.is_stop]

# %% [markdown]
# Here we are making a copy of our training dataset as it will be some kind of backup for us.
#
# now we will map above three functions on our copy of training dataset by using map function and it will return three new columns doc, removed_stops and lemmatized.

# %%
# create documents for all tuples of tokens
#docs = list(map(to_doc, train3.text))

train3 = train1.copy() 
# apply removing stop words to all
train3['removed_stops'] = list(map(remove_stops, train3.tokens))

# apply lemmatization to all
train3['lemmatized'] = list(map(lemmatize, train3.tokens))

# %% [markdown]
# Showing the top 5 rows of are dataset

# %%
train3.head()
# Out:
#                                                 text  label  \
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1
#
#                                               tokens  num_tokens  \
# 0  (Unfortunately, for, myself, -, I, stumbled, o...         166
# 0  (I, 've, seen, this, film, literally, over, 10...          99
# 0  (It, seems, to, be, a, perfect, day, for, swim...         174
# 0  (For, fans, of, Troma, or, the, Cyberpunk, gen...         137
# 0  (This, is, a, refreshing, ,, enjoyable, movie,...          68
#
#                                        removed_stops  \
# 0  [Unfortunately, -, stumbled, late, lifetime, ....
# 0  [seen, film, literally, 100, times, ..., absol...
# 0  [perfect, day, swimming, ., normal, family, wa...
# 0  [fans, Troma, Cyberpunk, genre, mixed, little,...
# 0  [refreshing, ,, enjoyable, movie, ., enjoyed, ...
#
#                                           lemmatized
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...

# %% [markdown]
# Actually, the upper to_doc function was taking too much time to complete its execution, so if we skip that function, then the result of lematization of words also changed.

# %% [markdown]
# ### **Another method for cleaning the data**

# %% [markdown]
# We have chosen another method for this purpose. We will first import re, which is actually a regular expression (or RE), that specifies a set of strings that match it, and then we will compile special characters and digits by using re.

# %%
import re
spec_chara = re.compile('[/(){}\[\]\|@,;]')  
ext_sym = re.compile('[^0-9a-z #+_]')

# %% [markdown]
# Than we will import Stop words library from spacy english language pakage and load "en_core_web_sm".

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load("en_core_web_sm", disable=['parser', 'tagger', 'ner'])
stops = STOP_WORDS

# %% [markdown]
# Here we create a normalizer function which will take a dataset as an input, make tokens of sentences, remove stopwords, and then perform lamatization.
#
# At the start, it will convert words to upper case, subract special characters, and then subract symbols and digits. After that, it will perform lamatization and remove stopwords, and lastly, it will return all the cleaned datasets by joining them.

# %%
def normalize(comment, lowercase, remove_stopwords):
    if lowercase:
        comment = comment.lower()
        comment = spec_chara.sub(' ', comment)
        comment = ext_sym.sub('', comment)
        
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stops):
                lemmatized.append(lemma)
    return " ".join(lemmatized)

# %% [markdown]
# Here we are simply applying the function which we have defined just in the above cell and storing clean text and text without stopwords in the dataframe by making new columns.

# %%
# The execution time will be between Five and six minutes.

train4 = train1.copy() 
train4['Text_After_Clean'] = train4['text'].apply(normalize, lowercase=True, remove_stopwords=False)
train4['stopwords removed'] = train4['text'].apply(normalize, lowercase=True, remove_stopwords=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# Showing the top 5 rows of our cleaned dataset

# %%
train4.head()
# Out:
#                                                 text  label  \
# 0  In New York, Andy Hanson (Philip Seymour Hoffm...      1
# 0  Jonathan Demme's directorial debut for Roger C...      1
# 0  I had never seen a silent movie until July 24,...      1
# 0  This film pulls you in from the get-go because...      1
# 0  Paulie sounds like the most saccharine, lachry...      1
#
#                                               tokens  num_tokens  \
# 0  (In, New, York, ,, Andy, Hanson, (, Philip, Se...         419
# 0  (Jonathan, Demme, 's, directorial, debut, for,...         463
# 0  (I, had, never, seen, a, silent, movie, until,...         209
# 0  (This, film, pulls, you, in, from, the, get, -...         335
# 0  (Paulie, sounds, like, the, most, saccharine, ...         265
#
#                                     Text_After_Clean  \
# 0  in new york andy hanson philip seymour hoffman...
# 0  jonathan demmes directorial debut for roger co...
# 0  i had never seen a silent movie until july 24 ...
# 0  this film pulls you in from the getgo because ...
# 0  paulie sounds like the most saccharine lachrym...
#
#                                    stopwords removed
# 0  new york andy hanson philip seymour hoffman ad...
# 0  jonathan demmes directorial debut roger corman...
# 0  seen silent movie july 24 2005 seen movie mary...
# 0  film pulls getgo grabs attention acknowledging...
# 0  paulie sounds like saccharine lachrymose senti...

# %% [markdown]
# We are just going to see the description of the label column.

# %%
train4.groupby('label').describe()
# Out:
#       num_tokens
#            count      mean         std   min    25%    50%     75%     max
# label
# 0         2500.0  273.1892  217.232224  14.0  141.0  197.0  336.25  2789.0
# 1         2500.0  273.1892  217.232224  14.0  141.0  197.0  336.25  2789.0

# %% [markdown]
# # **Preparation of Testing Data**

# %% [markdown]
# As our testing dataset will consist of both positive and negative labelled data, we will first take 250 positive labelled data and then take 250 negative labelled data and perform preprocessing on them.

# %% [markdown]
# ### **Positive Testing Dataset**

# %% [markdown]
# Here we store the path of our positive testing data in a variable and initialise a list named of files.

# %%
# Define relative path to folder containing the text files

files_folder = "/content/aclImdb/test/pos"
files = []

# %% [markdown]
# Now, by iterating a for loop, we extrect our (.txt format) filed data using the glob function and store it in the list in the form of a dataframe for each file data and name the column as 'text'.

# %%
# Create a dataframe list by using a list comprehension

files = [pd.read_csv(file, delimiter='\t', names =['text'] ) for file in glob.glob(os.path.join(files_folder ,"*.txt"))]

# %% [markdown]
# Here we will combine the whole list of dataframes and make a single dataframe.

# %%
# Concatenate the list of DataFrames into one

df_pos_test = pd.concat(files)

# %% [markdown]
# As the upper dataframe belongs to the positive class, we assigned it the label '1'. For this, we first made an array with a size of 12500 and then assigned it to the dataframe.

# %%
b = np.ones(12500, dtype = int)

df_pos_test = df_pos.assign(label=b)
df_pos_test.head()
# Out:
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1

# %% [markdown]
# Here we computed the total number of rows and columns just to show the characteristics of the dataframe.

# %%
# computing number of rows
rows = len(df_pos_test.axes[0])
 
# computing number of columns
cols = len(df_pos_test.axes[1])
 
print('\n')
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
df_pos_test.head()
# Out:
# Number of Rows:  12500
# Number of Columns:  2
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1

# %% [markdown]
# As we know, we want a total of only 500 (250 pos + 2500 neg) rows for our testing dataset, so, we split our dataframe and make a new dataframe which has a size of (250,2).

# %%
# splitting dataframe by row index
df_positive_test = df_pos_test.iloc[:250,:]
print("Shape of new dataframes - {}".format(df_positive_test.shape))
df_positive_test
# Out:
# Shape of new dataframes - (250, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      1
# 0   I've seen this film literally over 100 times.....      1
# 0   It seems to be a perfect day for swimming. A n...      1
# 0   For fans of Troma or the Cyberpunk genre mixed...      1
# 0   This is a refreshing, enjoyable movie. If you ...      1
# ..                                                ...    ...
# 0   This is a classic British comedy-thriller I ha...      1
# 0   Once you pick your jaw up from off the floor f...      1
# 0   This was the first "Walking Tall" movie I saw,...      1
# 0   Though I did not begin to read the "Classics" ...      1
# 0   Did Sandra (yes, she must have) know we would ...      1
#
# [250 rows x 2 columns]

# %% [markdown]
# ### **Negative Testing Dataset**

# %% [markdown]
# Now the above same factors are for the preparation of the testing dataset. we store the path of our negative testing data in a variable and initialise a list named of files.

# %%
# Define relative path to folder containing the text files

files_folder = "/content/aclImdb/test/neg"
files = []

# %% [markdown]
# Now, by iterating a for loop, we extrect our (.txt format) filed data using the glob function and store it in the list in the form of a dataframe for each file data and name the column as text.

# %%
# Create a dataframe list by using a list comprehension

files = [pd.read_csv(file, delimiter='\t', names =['text'] ) for file in glob.glob(os.path.join(files_folder ,"*.txt"))]

# %% [markdown]
# Here we will combine the whole list of dataframes and make a single dataframe.

# %%
# Concatenate the list of DataFrames into one

df_neg_test = pd.concat(files)

# %% [markdown]
# As the upper dataframe belongs to the negative class, we assigned it the label '0'. For this, we first made an array with a size of 12500 and then assigned it to the dataframe.

# %%
b = [0] * 12500

df_neg_test = df_pos.assign(label=b)
df_neg_test.head()
# Out:
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      0
# 0  I've seen this film literally over 100 times.....      0
# 0  It seems to be a perfect day for swimming. A n...      0
# 0  For fans of Troma or the Cyberpunk genre mixed...      0
# 0  This is a refreshing, enjoyable movie. If you ...      0

# %% [markdown]
# Here we computed the total number of rows and columns just to show the characteristics of the neagtive labeled dataframe.

# %%
# computing number of rows
rows = len(df_neg_test.axes[0])
 
# computing number of columns
cols = len(df_neg_test.axes[1])
 
print('\n')
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
df_neg_test.head()
# Out:
# Number of Rows:  12500
# Number of Columns:  2
#                                                 text  label
# 0  Unfortunately for myself - I stumbled onto thi...      0
# 0  I've seen this film literally over 100 times.....      0
# 0  It seems to be a perfect day for swimming. A n...      0
# 0  For fans of Troma or the Cyberpunk genre mixed...      0
# 0  This is a refreshing, enjoyable movie. If you ...      0

# %% [markdown]
# As we know, we want a total of only 500 (250 pos + 250 neg) rows for our testing dataset, so, we split our dataframe by using iloc and make a new dataframe which has a size of (250,2).

# %%
# splitting dataframe by row index
df_negative_test = df_neg_test.iloc[:250,:]
print("Shape of new dataframes - {}".format(df_negative_test.shape))
df_negative_test
# Out:
# Shape of new dataframes - (250, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      0
# 0   I've seen this film literally over 100 times.....      0
# 0   It seems to be a perfect day for swimming. A n...      0
# 0   For fans of Troma or the Cyberpunk genre mixed...      0
# 0   This is a refreshing, enjoyable movie. If you ...      0
# ..                                                ...    ...
# 0   This is a classic British comedy-thriller I ha...      0
# 0   Once you pick your jaw up from off the floor f...      0
# 0   This was the first "Walking Tall" movie I saw,...      0
# 0   Though I did not begin to read the "Classics" ...      0
# 0   Did Sandra (yes, she must have) know we would ...      0
#
# [250 rows x 2 columns]

# %% [markdown]
# ### **Combines Both datasets**

# %% [markdown]
# Now we have our positive and negative labelled dataframes, so we will merge them into a single dataframe by using the concat function of the pandas library. Then in the results we will get our testing dataset size of (500,2).

# %%
frames = [df_positive_test, df_negative_test]
  
test = pd.concat(frames)
print("Shape of new train dataframe - {}".format(test.shape))
display(test)
# Out:
# Shape of new train dataframe - (500, 2)
#                                                  text  label
# 0   Unfortunately for myself - I stumbled onto thi...      1
# 0   I've seen this film literally over 100 times.....      1
# 0   It seems to be a perfect day for swimming. A n...      1
# 0   For fans of Troma or the Cyberpunk genre mixed...      1
# 0   This is a refreshing, enjoyable movie. If you ...      1
# ..                                                ...    ...
# 0   This is a classic British comedy-thriller I ha...      0
# 0   Once you pick your jaw up from off the floor f...      0
# 0   This was the first "Walking Tall" movie I saw,...      0
# 0   Though I did not begin to read the "Classics" ...      0
# 0   Did Sandra (yes, she must have) know we would ...      0
#
# [500 rows x 2 columns]

# %% [markdown]
# ### **Preprocessing on Training Dataset**

# %% [markdown]
# By using spacy, we load "en_core_web_sm", which is a small English pipeline trained on written web text that includes vocabulary, syntax, and entities.
#
# Then we make a new column named "tokens" in our training dataset in which we store our text data after tokenization.

# %%
nlp = spacy.load("en_core_web_sm")
test1 = test.copy()
test1["tokens"] = test["text"].apply(lambda x: nlp.tokenizer(x))

test1.head()
# Out:
#                                                 text  label  \
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1
#
#                                               tokens
# 0  (Unfortunately, for, myself, -, I, stumbled, o...
# 0  (I, 've, seen, this, film, literally, over, 10...
# 0  (It, seems, to, be, a, perfect, day, for, swim...
# 0  (For, fans, of, Troma, or, the, Cyberpunk, gen...
# 0  (This, is, a, refreshing, ,, enjoyable, movie,...

# %% [markdown]
# Here we create a new column named "num_tokens", store the sum of tokens in each document, and make a histogram by using the seaborn library to visualise the total number of tokens per movie review.

# %%
# Sum the number of tokens in each Doc

train1['num_tokens'] = [len(token) for token in train1.tokens]

# Visualize histogram of tokens per movie review

g = sns.distplot(train1.num_tokens)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Here we have written three functions:
#
# First is for making a spacy document in which we will join the words into a string.
# In the second function, we are actually filtering the tokens in such a way that it will skip stopwords and only pick the non_stopwords tokens. Basically, we are removing stopwords.
# The third one is for lemmatization, which we use . For each token, use lemma_keyword (access each token with a for loop).

# %%
 def to_doc(words:tuple) -> spacy.tokens.Doc:
    # Create SpaCy documents by joining the words into a string
    return nlp(' '.join(words))

def remove_stops(doc) -> list:
    # Filter out stop words by using the `token.is_stop` attribute
    return [token.text for token in doc if not token.is_stop]

def lemmatize(doc) -> list:
    # Take the `token.lemma_` of each non-stop word
    return [token.lemma_ for token in doc if not token.is_stop]

# %% [markdown]
# Here we are making a copy of our training dataset as it will be some kind of backup for us.
#
# now we will map above three functions on our copy of training dataset by using map function and it will return three new columns doc, removed_stops and lemmatized.

# %%
# create documents for all tuples of tokens
#docs = list(map(to_doc, train3.text))

test3 = test1.copy() 
# apply removing stop words to all
test3['removed_stops'] = list(map(remove_stops, test3.tokens))

# apply lemmatization to all
test3['lemmatized'] = list(map(lemmatize, test3.tokens))

# %% [markdown]
# Showing the top 5 rows of are dataset

# %%
test3.head()
# Out:
#                                                 text  label  \
# 0  Unfortunately for myself - I stumbled onto thi...      1
# 0  I've seen this film literally over 100 times.....      1
# 0  It seems to be a perfect day for swimming. A n...      1
# 0  For fans of Troma or the Cyberpunk genre mixed...      1
# 0  This is a refreshing, enjoyable movie. If you ...      1
#
#                                               tokens  \
# 0  (Unfortunately, for, myself, -, I, stumbled, o...
# 0  (I, 've, seen, this, film, literally, over, 10...
# 0  (It, seems, to, be, a, perfect, day, for, swim...
# 0  (For, fans, of, Troma, or, the, Cyberpunk, gen...
# 0  (This, is, a, refreshing, ,, enjoyable, movie,...
#
#                                        removed_stops  \
# 0  [Unfortunately, -, stumbled, late, lifetime, ....
# 0  [seen, film, literally, 100, times, ..., absol...
# 0  [perfect, day, swimming, ., normal, family, wa...
# 0  [fans, Troma, Cyberpunk, genre, mixed, little,...
# 0  [refreshing, ,, enjoyable, movie, ., enjoyed, ...
#
#                                           lemmatized
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...
# 0  [, , , , , , , , , , , , , , , , , , , , , , ,...

# %% [markdown]
# Actually, the upper to_doc function was taking too much time to complete its execution, so if we skip that function, then the result of lematization of words also changed.

# %% [markdown]
# ### **Another method for cleaning the data**

# %% [markdown]
# So we have chosen another method for this purpose. We will first import re, which is actually a regular expression (or RE), that specifies a set of strings that match it, and then we will compile special characters and digits by using re.

# %%
import re
spec_chara = re.compile('[/(){}\[\]\|@,;]')  
ext_sym = re.compile('[^0-9a-z #+_]')

# %% [markdown]
# Than we will import Stop words library from spacy english language pakage and load "en_core_web_sm".

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load("en_core_web_sm", disable=['parser', 'tagger', 'ner'])
stops = STOP_WORDS

# %% [markdown]
# Here we create a normalizer function which will take a dataset as an input, make tokens of sentences, remove stopwords, and then perform lamatization.
#
# At the start, it will convert words to upper case, subract special characters, and then subract symbols and digits. After that, it will perform lamatization and remove stopwords, and lastly, it will return all the cleaned datasets by joining them.

# %%
def normalize(comment, lowercase, remove_stopwords):
    if lowercase:
        comment = comment.lower()
        comment = spec_chara.sub(' ', comment)
        comment = ext_sym.sub('', comment)
        
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stops):
                lemmatized.append(lemma)
    return " ".join(lemmatized)

# %% [markdown]
# Here we are simply applying the function which we have defined just in the above cell and storing clean text and text without stopwords in the dataframe by making new columns.

# %%
# The execution time will be between four and five minutes.

test4 = test1.copy() 
test4['Text_After_Clean'] = test4['text'].apply(normalize, lowercase=True, remove_stopwords=False)
test4['stopwords removed'] = test4['text'].apply(normalize, lowercase=True, remove_stopwords=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# Showing the top 5 rows of our cleaned dataset

# %%
train4.head()
# Out:
#                                                 text  label  \
# 0  In New York, Andy Hanson (Philip Seymour Hoffm...      1
# 0  Jonathan Demme's directorial debut for Roger C...      1
# 0  I had never seen a silent movie until July 24,...      1
# 0  This film pulls you in from the get-go because...      1
# 0  Paulie sounds like the most saccharine, lachry...      1
#
#                                               tokens  num_tokens  \
# 0  (In, New, York, ,, Andy, Hanson, (, Philip, Se...         419
# 0  (Jonathan, Demme, 's, directorial, debut, for,...         463
# 0  (I, had, never, seen, a, silent, movie, until,...         209
# 0  (This, film, pulls, you, in, from, the, get, -...         335
# 0  (Paulie, sounds, like, the, most, saccharine, ...         265
#
#                                     Text_After_Clean  \
# 0  in new york andy hanson philip seymour hoffman...
# 0  jonathan demmes directorial debut for roger co...
# 0  i had never seen a silent movie until july 24 ...
# 0  this film pulls you in from the getgo because ...
# 0  paulie sounds like the most saccharine lachrym...
#
#                                    stopwords removed
# 0  new york andy hanson philip seymour hoffman ad...
# 0  jonathan demmes directorial debut roger corman...
# 0  seen silent movie july 24 2005 seen movie mary...
# 0  film pulls getgo grabs attention acknowledging...
# 0  paulie sounds like saccharine lachrymose senti...

# %% [markdown]
# We are just going to see the description of the label column.

# %%
test4.groupby('label').describe()
# Out:
#        text                                                                 \
#       count unique                                                top freq
# label
# 0       250    250  In New York, Andy Hanson (Philip Seymour Hoffm...    1
# 1       250    250  In New York, Andy Hanson (Philip Seymour Hoffm...    1
#
#       tokens                                                                 \
#        count unique                                                top freq
# label
# 0        250    250  (In, New, York, ,, Andy, Hanson, (, Philip, Se...    1
# 1        250    250  (In, New, York, ,, Andy, Hanson, (, Philip, Se...    1
#
#       Text_After_Clean         \
#                  count unique
# label
# 0                  250    250
# 1                  250    250
#
#                                                                \
#                                                      top freq
# label
# 0      in new york andy hanson philip seymour hoffman...    1
# 1      in new york andy hanson philip seymour hoffman...    1
#
#       stopwords removed         \
#                   count unique
# label
# 0                   250    250
# 1                   250    250
#
#
#                                                      top freq
# label
# 0      new york andy hanson philip seymour hoffman ad...    1
# 1      new york andy hanson philip seymour hoffman ad...    1

# %% [markdown]
# # **Unsupervised Learning Dataset**

# %% [markdown]
# Here we store the path of data (which will used for unsupervised learning) in a variable and initialise a list named of files.

# %%
# Define relative path to folder containing the text files

files_folder = "/content/aclImdb/train/unsup" 
files = []

# %% [markdown]
# Now, by iterating a for loop, we extrect our (.txt format) filed data using the glob function and store it in the list in the form of a dataframe for each file data and name the column as 'text'.

# %%
# Create a dataframe list by using a list comprehension
# The execution time will be between half and one minute. 

files = [pd.read_csv(file, delimiter='\t', names =['text'] ) for file in glob.glob(os.path.join(files_folder ,"*.txt"))]

# %% [markdown]
# Here we will combine the whole list of dataframes and make a single dataframe.

# %%
# Concatenate the list of DataFrames into one

df_unsup = pd.concat(files)

# %% [markdown]
# Here we computed the total number of rows and columns just to show the characteristics of the Un labeled dataframe.

# %%
# computing number of rows
rows = len(df_unsup.axes[0])
 
# computing number of columns
cols = len(df_unsup.axes[1])

# Simply print

print('\n')
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
df_unsup.head()
# Out:
# Number of Rows:  50000
# Number of Columns:  1
#                                                 text
# 0  Heartstopper wasn't to bad for a low budget B ...
# 0  Originally made for the cinema, this film was ...
# 0  The Education of Charlie Banks was an excellen...
# 0  I know I'm going against the grain here, becau...
# 0  In this movie director Stephen Frears tries to...

# %% [markdown]
# We will take only 5000 rows to reduce the execution time.

# %%
# splitting dataframe by row index

df_un = df_unsup.iloc[:5000,:]
print("Shape of new dataframes - {}".format(df_un.shape))
df_un
# Out:
# Shape of new dataframes - (5000, 1)
#                                                  text
# 0   Heartstopper wasn't to bad for a low budget B ...
# 0   Originally made for the cinema, this film was ...
# 0   The Education of Charlie Banks was an excellen...
# 0   I know I'm going against the grain here, becau...
# 0   In this movie director Stephen Frears tries to...
# ..                                                ...
# 0   At first, I thought this was going to be anoth...
# 0   WAITING FOR GUFFMAN is my favorite movie of al...
# 0   i would say that I've watched only the past 3 ...
# 0   I starting watching this on Comedy Central and...
# 0   Wow...<br /><br />It's been twelve hours since...
#
# [5000 rows x 1 columns]

# %% [markdown]
# ### **Preprocessing on unsup Dataset**

# %% [markdown]
# Now, by using spacy, we load "en_core_web_sm", which is a small English pipeline trained on written web text that includes vocabulary, syntax, and entities.
#
# Then we make a new column named "tokens" in our training dataset in which we store our text data after tokenization.

# %%
nlp = spacy.load("en_core_web_sm")
df_unsup["tokens"] = df_unsup["text"].apply(lambda x: nlp.tokenizer(x))

df_unsup.head()
# Out:
#                                                 text  \
# 0  Heartstopper wasn't to bad for a low budget B ...
# 0  Originally made for the cinema, this film was ...
# 0  The Education of Charlie Banks was an excellen...
# 0  I know I'm going against the grain here, becau...
# 0  In this movie director Stephen Frears tries to...
#
#                                               tokens
# 0  (Heartstopper, was, n't, to, bad, for, a, low,...
# 0  (Originally, made, for, the, cinema, ,, this, ...
# 0  (The, Education, of, Charlie, Banks, was, an, ...
# 0  (I, know, I, 'm, going, against, the, grain, h...
# 0  (In, this, movie, director, Stephen, Frears, t...

# %% [markdown]
# Here we create a new column named "num_tokens", store the sum of tokens in each document, and make a histogram by using the seaborn library to visualise the total number of tokens per movie review.

# %%
# Sum the number of tokens in each Doc

df_unsup['num_tokens'] = [len(token) for token in df_unsup.tokens]

# Visualize histogram of tokens per movie review

g = sns.distplot(df_unsup.num_tokens)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# We have chosen another method for this purpose. We will first import re, which is actually a regular expression (or RE), that specifies a set of strings that match it, and then we will compile special characters and digits by using re.

# %%
import re
spec_chara = re.compile('[/(){}\[\]\|@,;]')  
ext_sym = re.compile('[^0-9a-z #+_]')

# %% [markdown]
# Than we will import Stop words library from spacy english language pakage and load "en_core_web_sm".

# %%
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load("en_core_web_sm", disable=['parser', 'tagger', 'ner'])
stops = STOP_WORDS

# %% [markdown]
# Here we create a normalizer function which will take a dataset as an input, make tokens of sentences, remove stopwords, and then perform lamatization.
#
# At the start, it will convert words to upper case, subract special characters, and then subract symbols and digits. After that, it will perform lamatization and remove stopwords, and lastly, it will return all the cleaned datasets by joining them.

# %%
def normalize(comment, lowercase, remove_stopwords):
    if lowercase:
        comment = comment.lower()
        comment = spec_chara.sub(' ', comment)
        comment = ext_sym.sub('', comment)
        
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stops):
                lemmatized.append(lemma)
    return " ".join(lemmatized)

# %% [markdown]
# Here we are simply applying the function which we have defined just in the above cell and storing clean text and text without stopwords in the dataframe by making new columns.

# %%
# The execution time will be between seven and eight minutes.

df_unsup = df_unsup.copy() 
df_unsup['stopwords removed'] = df_unsup['text'].apply(normalize, lowercase=True, remove_stopwords=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %% [markdown]
# Showing the top 5 rows of our cleaned dataset

# %%
df_unsup.head()
# Out:
#                                                 text  \
# 0  Heartstopper wasn't to bad for a low budget B ...
# 0  Originally made for the cinema, this film was ...
# 0  The Education of Charlie Banks was an excellen...
# 0  I know I'm going against the grain here, becau...
# 0  In this movie director Stephen Frears tries to...
#
#                                               tokens  num_tokens  \
# 0  (Heartstopper, was, n't, to, bad, for, a, low,...         139
# 0  (Originally, made, for, the, cinema, ,, this, ...         137
# 0  (The, Education, of, Charlie, Banks, was, an, ...         144
# 0  (I, know, I, 'm, going, against, the, grain, h...         465
# 0  (In, this, movie, director, Stephen, Frears, t...         680
#
#                                    stopwords removed
# 0  heartstopper nt bad low budget b slasher movie...
# 0  originally cinema film deemed awful distributo...
# 0  education charlie banks excellent film indepen...
# 0  know m going grain comments favourable movie p...
# 0  movie director stephen frears tries tell dr je...

# %% [markdown]
# # **Transformer**

# %% [markdown]
# ### **Why DistilBert?**

# %% [markdown]
# "DistilBERT is a small, fast, cheap and light Transformer model based on the BERT architecture."
#
# Why DistilBert?
#
# 1. DistilBERT gives some extraordinary results on some downstream tasks
# 2. Distil-BERT has 97% of BERT’s performance while being trained on half of the parameters of BERT.
# 3. The DistilBERT transformer is a light, small, and fast version of its bigger BERT version.
# 4. It has achieved 0.6% less accuracy than BERT while the model is 40% smaller.
# 5. It has 40% less parameters than BERT and yet 60% faster than it.

# %% [markdown]
# ### **Libraries to use**

# %%
import os                              # to interact with the underlying operating system.
import tensorflow as tf                # converts regular python code to a callable Tensorflow graph function
import tensorflow_hub as hub           # library for reusable machine learning
import tensorflow_datasets as tfds     # defines a collection of datasets ready-to-use with TensorFlow
import tensorflow_text as text         # provides a collection of text related classes and ops

# %% [markdown]
# ### **Import Bert Algorithm**

# %% [markdown]
# Now we will import BERT model and get embeding vectors for few sample statements

# %%
bert_preprocess = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_preprocess/3")
bert_encoder = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/4")

# %% [markdown]
# ### **Build Model**

# %% [markdown]
# At the start, we will create our input layer in which we will pass the shape, which encoding bert is passing, and the name of the layer. Then we will use bert_preprocess, which will retune preprocessed text to us, and then, by using bert_encoder, we will get output as a result.

# %%
# Bert layers
text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
preprocessed_text = bert_preprocess(text_input)
outputs = bert_encoder(preprocessed_text)

# %% [markdown]
# Now we will creat a drop out layer and pass 0.1 value that means 0.1 percent nurons to stop. And as we know it is an functional model so we will supply nuron laye a input. The input will be the pooled out of output of previous layer.
#
# The second layer we have created it is dense laye, and pass it value 1, because 1 is telling us that movie review is positive or not. And use sigmoid as an activation layer. Also the input of this laye will be the output of privious layer.
#
# At the last, we will create our final model.

# %%
# Neural network layers
l = tf.keras.layers.Dropout(0.1, name="dropout")(outputs['pooled_output'])
l = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(l)

# Use inputs and outputs to construct a final model
model = tf.keras.Model(inputs=[text_input], outputs = [l])

# %% [markdown]
# Now here we are defining during training which parameters (accuracy or precision) will be shown for each epoch.
#
# In model compile the adam is an optimizer, and binary_crossentropy is used because our output is binary(1/0).

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall')]

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

# %% [markdown]
# ### **Spliting Datasets for training and testing**

# %% [markdown]
# Here we are making X-train using the feature column and y_train using the label column for training purposes.

# %%
X_train = train4['stopwords removed'].copy()
y_train = train4['label'].copy()

# %% [markdown]
# Here we are making X-test using the feature column and y_test using the label column for testing purposes.

# %%
X_test= test4['stopwords removed'].copy()
y_test = test4['label'].copy()

# %% [markdown]
# Also we can use sklearn pakage for this purpose

# %%
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(train4['stopwords removed'],train4['label'], stratify=train4['label'])

# %% [markdown]
# ## **Training of Transformer**

# %% [markdown]
# ### **Using 10 Epochs**

# %% [markdown]
# Here we are training our model using only 10 epochs.

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 50s 321ms/step - loss: 0.7018 - accuracy: 0.4926 - precision: 0.4925 - recall: 0.4860
# Epoch 2/10
# 157/157 [==============================] - 53s 339ms/step - loss: 0.6990 - accuracy: 0.4942 - precision: 0.4942 - recall: 0.4932
# Epoch 3/10
# 157/157 [==============================] - 53s 335ms/step - loss: 0.7005 - accuracy: 0.4974 - precision: 0.4974 - recall: 0.4920
# Epoch 4/10
# 157/157 [==============================] - 53s 335ms/step - loss: 0.7041 - accuracy: 0.4844 - precision: 0.4838 - recall: 0.4656
# Epoch 5/10
# 157/157 [==============================] - 55s 350ms/step - loss: 0.7017 - accuracy: 0.4986 - precision: 0.4986 - recall: 0.5008
# Epoch 6/10
# 157/157 [==============================] - 53s 340ms/step - loss: 0.7012 - accuracy: 0.5096 - precision: 0.5095 - recall: 0.5152
# Epoch 7/10
# 157/157 [==============================] - 53s 339ms/step - loss: 0.7023 - accuracy: 0.4978 - precision: 0.4976 - recall: 0.4572
# Epoch 8/10
# 157/157 [==============================] - 56s 354ms/step - loss: 0.7023 - accuracy: 0.5032 - precision: 0.5032 - recall: 0.4960
# Epoch 9/10
# 157/157 [==============================] - 53s 340ms/step - loss: 0.7047 - accuracy: 0.4868 - precision: 0.4872 - recall: 0.5044
# Epoch 10/10
# 157/157 [==============================] - 53s 338ms/step - loss: 0.7029 - accuracy: 0.4896 - precision: 0.4895 - recall: 0.4828

# %% [markdown]
# After training, now we will evaluate our model.The  evaluate() is for evaluating the already trained model using the validation or test data and the corresponding labels. Returns the loss value and metrics values for the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 5s 325ms/step - loss: 0.6943 - accuracy: 0.5000 - precision: 0.5000 - recall: 0.0240
# [0.6943285465240479, 0.5, 0.5, 0.024000000208616257]

# %% [markdown]
# ## **Testing of Transformer**

# %%
y_predicted = model.predict(X_test)
y_predicted = y_predicted.flatten()

# %% [markdown]
# Here we are defining a threshold such that if the predicted value is greater than 0.5, we store 1 in the array, otherwise 0.

# %%
# defining a Threshold 

y_predicted = np.where(y_predicted > 0.5, 1, 0)

# %% [markdown]
# ### **Making confusion matrix**

# %% [markdown]
# Using sklearn we will import confusion matrix and generate a Classification report by which we can see the precision, recall and accuracy.

# %%
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[244,   6],
#        [244,   6]])

# %% [markdown]
# Our report of our results is as below.

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.95      0.65       625
#            1       0.39      0.03      0.06       625
#
#     accuracy                           0.49      1250
#    macro avg       0.44      0.49      0.35      1250
# weighted avg       0.44      0.49      0.35      1250

# %% [markdown]
# Now we will use pyplot and seaborn libraries and visualise the results in the form of a heatmap.

# %%
from matplotlib import pyplot as plt
import seaborn as sn
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(33.0, 0.5, 'Truth')

# %% [markdown]
# ### **Using 20 Epoches**

# %% [markdown]
# Here we are training our model using only 20 epochs.

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 157/157 [==============================] - 57s 364ms/step - loss: 0.7005 - accuracy: 0.4848 - precision: 0.4860 - recall: 0.5280
# Epoch 2/20
# 157/157 [==============================] - 55s 352ms/step - loss: 0.7067 - accuracy: 0.4978 - precision: 0.4978 - recall: 0.5036
# Epoch 3/20
# 157/157 [==============================] - 56s 358ms/step - loss: 0.6982 - accuracy: 0.5012 - precision: 0.5012 - recall: 0.5136
# Epoch 4/20
# 157/157 [==============================] - 55s 348ms/step - loss: 0.7016 - accuracy: 0.4942 - precision: 0.4944 - recall: 0.5140
# Epoch 5/20
# 157/157 [==============================] - 53s 340ms/step - loss: 0.7024 - accuracy: 0.5032 - precision: 0.5032 - recall: 0.5072
# Epoch 6/20
# 157/157 [==============================] - 56s 358ms/step - loss: 0.6982 - accuracy: 0.4992 - precision: 0.4992 - recall: 0.4940
# Epoch 7/20
# 157/157 [==============================] - 54s 342ms/step - loss: 0.7004 - accuracy: 0.4922 - precision: 0.4926 - recall: 0.5184
# Epoch 8/20
# 157/157 [==============================] - 55s 348ms/step - loss: 0.7005 - accuracy: 0.4872 - precision: 0.4856 - recall: 0.4312
# Epoch 9/20
# 157/157 [==============================] - 55s 349ms/step - loss: 0.7038 - accuracy: 0.5048 - precision: 0.5049 - recall: 0.4984
# Epoch 10/20
# 157/157 [==============================] - 54s 341ms/step - loss: 0.6983 - accuracy: 0.4952 - precision: 0.4955 - recall: 0.5284
# Epoch 11/20
# 157/157 [==============================] - 56s 356ms/step - loss: 0.7025 - accuracy: 0.5036 - precision: 0.5036 - recall: 0.5040
# Epoch 12/20
# 157/157 [==============================] - 53s 341ms/step - loss: 0.7000 - accuracy: 0.4990 - precision: 0.4990 - recall: 0.4960
# Epoch 13/20
# 157/157 [==============================] - 55s 349ms/step - loss: 0.7016 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4880
# Epoch 14/20
# 157/157 [==============================] - 55s 348ms/step - loss: 0.6998 - accuracy: 0.5076 - precision: 0.5081 - recall: 0.4796
# Epoch 15/20
# 157/157 [==============================] - 53s 341ms/step - loss: 0.7027 - accuracy: 0.4854 - precision: 0.4852 - recall: 0.4772
# Epoch 16/20
# 157/157 [==============================] - 56s 355ms/step - loss: 0.7026 - accuracy: 0.4960 - precision: 0.4961 - recall: 0.5036
# Epoch 17/20
# 157/157 [==============================] - 54s 341ms/step - loss: 0.6998 - accuracy: 0.4908 - precision: 0.4905 - recall: 0.4744
# Epoch 18/20
# 157/157 [==============================] - 55s 350ms/step - loss: 0.6991 - accuracy: 0.4928 - precision: 0.4932 - recall: 0.5216
# Epoch 19/20
# 157/157 [==============================] - 54s 345ms/step - loss: 0.7042 - accuracy: 0.4942 - precision: 0.4936 - recall: 0.4496
# Epoch 20/20
# 157/157 [==============================] - 53s 340ms/step - loss: 0.7029 - accuracy: 0.4928 - precision: 0.4933 - recall: 0.5336

# %% [markdown]
# After training, now we will evaluate our model.The evaluate() is for evaluating the already trained model using the validation or test data and the corresponding labels. Returns the loss value and metrics values for the model.

# %%
model.evaluate(X_test, y_test)
# Out:
# 16/16 [==============================] - 5s 329ms/step - loss: 0.6939 - accuracy: 0.5000 - precision: 0.5000 - recall: 0.1360
# [0.693879246711731, 0.5, 0.5, 0.13600000739097595]

# %% [markdown]
# ## **Testing of Transformer**

# %%
y_predicted = model.predict(X_test)
y_predicted = y_predicted.flatten()

# %% [markdown]
# Here we are defining a threshold such that if the predicted value is greater than 0.5, we store 1 in the array, otherwise 0.

# %%
# defining a Threshold 

y_predicted = np.where(y_predicted > 0.5, 1, 0)

# %% [markdown]
# ### **Making confusion matrix**

# %% [markdown]
# Using sklearn we will import confusion matrix and generate a Classification report by which we can see the precision, recall and accuracy.

# %%
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[216,  34],
#        [216,  34]])

# %% [markdown]
# Our report of our results is as below.

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.86      0.63       250
#            1       0.50      0.14      0.21       250
#
#     accuracy                           0.50       500
#    macro avg       0.50      0.50      0.42       500
# weighted avg       0.50      0.50      0.42       500

# %% [markdown]
# Now we will use pyplot and seaborn libraries and visualise the results in the form of a heatmap.

# %%
from matplotlib import pyplot as plt
import seaborn as sn
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(33.0, 0.5, 'Truth')
